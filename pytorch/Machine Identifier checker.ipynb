# %%
import requests

# 文件路径
input_file_path = r'C:\Users\96446\Documents\GitHub\data/mmkg/FBDB15K/norm/ent_ids_1'  # Ensure this path is correct and accessible

FB15K = {}

# Reading the file and filling the FB15K dictionary
with open(input_file_path, 'r') as file:
    for line in file:
        index, fb_id = line.strip().split('\t')
        FB15K[index] = fb_id

output_file_path = 'output_with_types.txt'  # 输出文件路径, make sure your environment has write permissions to this path or directory

sparql_url = "https://query.wikidata.org/sparql"

# 准备输出文件
with open(output_file_path, 'w', encoding='utf-8') as output_file:
    # 写入文件头
    output_file.write("Index,Freebase ID,Entity,Type\n")
    
    for index, fb_id in FB15K.items():
        query = f"""
        SELECT ?item ?itemLabel ?itemTypeLabel WHERE {{
          # ?item wdt:P646 "{fb_id}" .
          # ?item wdt:P31 ?itemType .
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
        }}"""
        
        response = requests.get(sparql_url, params={'format': 'json', 'query': query})
        data = response.json()
        for item in data["results"]["bindings"]:
            print(f"Freebase ID: {fb_id}, Entity: {item['itemLabel']['value']}, Type: {item['itemTypeLabel']['value']}")
# Out:
# Freebase ID: /m/027rn, Entity: Dominican Republic, Type: country
# Freebase ID: /m/027rn, Entity: Dominican Republic, Type: island country
# Freebase ID: /m/027rn, Entity: Dominican Republic, Type: sovereign state
# Freebase ID: /m/027rn, Entity: Dominican Republic, Type: archipelagic state
# Freebase ID: /m/06cx9, Entity: republic, Type: form of state
# Freebase ID: /m/06cx9, Entity: republic, Type: form of government
# Freebase ID: /m/017dcd, Entity: Mighty Morphin Power Rangers, Type: television series
# Freebase ID: /m/06v8s0, Entity: Wendee Lee, Type: human
# Freebase ID: /m/07s9rl0, Entity: drama film, Type: film genre
# Freebase ID: /m/0170z3, Entity: American History X, Type: film
# Freebase ID: /m/01sl1q, Entity: Michelle Rodriguez, Type: human
# Freebase ID: /m/044mz_, Entity: Naveen Andrews, Type: human
# Freebase ID: /m/0cnk2q, Entity: Australia men's national soccer team, Type: national association football team
# Freebase ID: /m/02nzb8, Entity: midfielder, Type: association football position
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[18], line 32
#      24 query = f"""
#      25 SELECT ?item ?itemLabel ?itemTypeLabel WHERE {{
#      26   ?item wdt:P646 "{fb_id}" .
#      27   ?item wdt:P31 ?itemType .
#      28   SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
#      29 }}"""
#      31 response = requests.get(sparql_url, params={'format': 'json', 'query': query})
# ---> 32 data = response.json()
#      33 data = response.json()
#      34 for item in data["results"]["bindings"]:
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import requests
import time

input_file_path = r'C:\Users\96446\Documents\GitHub\data/mmkg/FBDB15K/norm/ent_ids_1'
sparql_url = "https://query.wikidata.org/sparql"

FB15K = {}
FB15K_Updated = {}

# 读取Freebase IDs
with open(input_file_path, 'r') as file:
    for line in file:
        index, fb_id = line.strip().split('\t')
        FB15K[index] = fb_id

def fetch_data_with_backoff(query):
    backoff_time = 1  # 开始退避时间为1秒
    max_backoff_time = 120  # 最大退避时间为120秒
    while backoff_time <= max_backoff_time:
        response = requests.get(sparql_url, params={'format': 'json', 'query': query})
        if response.status_code == 429:  # 处理速率限制
            print(f"Rate limited. Retrying in {backoff_time} seconds...")
            time.sleep(backoff_time)
            backoff_time *= 2  # 指数退避
        elif response.status_code == 200:
            return response.json()  # 成功获取数据
        else:
            response.raise_for_status()  # 抛出其他HTTP错误

# 查询每个Freebase ID的实体和类型
for index, fb_id in FB15K.items():
    query = f"""
    SELECT ?item ?itemLabel ?itemTypeLabel WHERE {{
      # ?item wdt:P646 "{fb_id}" .
      # ?item wdt:P31 ?itemType .
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
    }}"""
    try:
        data = fetch_data_with_backoff(query)
        if data.get("results", {}).get("bindings", []):
            item = data["results"]["bindings"][0]  # 取第一个结果
            entity = item.get('itemLabel', {}).get('value', 'Unknown entity')
            entity_type = item.get('itemTypeLabel', {}).get('value', 'Unknown type')
            FB15K_Updated[fb_id] = {'entity_name': entity, 'entity_type': entity_type}
            print(f"Freebase ID: {fb_id}, Entity: {entity}, Type: {entity_type}")
        else:
            print(f"No data found for Freebase ID: {fb_id}")
    except requests.exceptions.HTTPError as e:
        print(f"Failed to fetch data for {fb_id}: {e}")

print("Finished updating the dictionary with entity types.")
# Out:
# Freebase ID: /m/027rn, Entity: Dominican Republic, Type: country
# Freebase ID: /m/06cx9, Entity: republic, Type: form of state
# Freebase ID: /m/017dcd, Entity: Mighty Morphin Power Rangers, Type: television series
# Freebase ID: /m/06v8s0, Entity: Wendee Lee, Type: human
# Freebase ID: /m/07s9rl0, Entity: drama film, Type: film genre
# Freebase ID: /m/0170z3, Entity: American History X, Type: film
# Freebase ID: /m/01sl1q, Entity: Michelle Rodriguez, Type: human
# Freebase ID: /m/044mz_, Entity: Naveen Andrews, Type: human
# Freebase ID: /m/0cnk2q, Entity: Australia men's national soccer team, Type: national association football team
# Freebase ID: /m/02nzb8, Entity: midfielder, Type: association football position
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02_j1w, Entity: defender, Type: association football position
# Freebase ID: /m/01cwm1, Entity: Stoke City F.C., Type: association football club
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/059ts, Entity: Northwest Territories, Type: territory of Canada
# Freebase ID: /m/03h_f4, Entity: 34th Canadian Parliament, Type: term of the Canadian federal parliament
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/011yn5, Entity: As Good as It Gets, Type: film
# Freebase ID: /m/01pjr7, Entity: Harold Ramis, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04nrcg, Entity: Maldives national football team, Type: national association football team
# Freebase ID: /m/02sdk9v, Entity: forward, Type: association football position
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07nznf, Entity: Bryan Singer, Type: human
# Freebase ID: /m/014lc_, Entity: Star Trek: Nemesis, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05cvgl, Entity: The Remains of the Day, Type: film
# Freebase ID: /m/04kxsb, Entity: BAFTA Award for Best Actor in a Leading Role, Type: British Academy Film Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02qyp19, Entity: BAFTA Award for Best Original Screenplay, Type: British Academy Film Awards
# Freebase ID: /m/02d413, Entity: Philadelphia, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02vk52z, Entity: World Bank, Type: international financial institution
# Freebase ID: /m/01crd5, Entity: Vietnam, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0q9kd, Entity: Danny DeVito, Type: human
# Freebase ID: /m/0184jc, Entity: Guy Pearce, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09w1n, Entity: alpine skiing, Type: type of sport
# Freebase ID: /m/0sx8l, Entity: 1980 Winter Olympics, Type: Winter Olympic Games
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/03q5t
# Freebase ID: /m/07y_7, Entity: violin, Type: type of musical instrument
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0gqng, Entity: Academy Award for Best International Feature Film, Type: Academy Awards
# Freebase ID: /m/073hkh, Entity: 61st Academy Awards, Type: Academy Awards ceremony
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0b76d_m, Entity: Anonymous, Type: film
# Freebase ID: /m/029j_, Entity: DVD, Type: physical media format
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04ztj, Entity: marriage, Type: institution
# Freebase ID: /m/012v9y, Entity: William Holden, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/014_x2, Entity: City of Angels, Type: film
# Freebase ID: /m/012ljv, Entity: Gabriel Yared, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0ds35l9, Entity: Bridesmaids, Type: film
# Freebase ID: /m/05r4w, Entity: Portugal, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/015qsq, Entity: Serpico, Type: film
# Freebase ID: /m/02bjrlw, Entity: Italian, Type: language
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04bdxl, Entity: Catherine Keener, Type: human
# Freebase ID: /m/02s2ft, Entity: Chris Cooper, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0677ng, Entity: Swizz Beatz, Type: human
# Freebase ID: /m/03ckfl9, Entity: experimental music, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03zj9, Entity: Ithaca College, Type: private university
# Freebase ID: /m/059rby, Entity: New York, Type: U.S. state
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0157m, Entity: Bill Clinton, Type: human
# Freebase ID: /m/063k3h, Entity: Scotch-Irish Americans, Type: ethnic group
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01ky7c, Entity: University of Massachusetts Amherst, Type: university
# Freebase ID: /m/019v9k, Entity: bachelor's degree, Type: educational stage
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02681vq, Entity: Latin Grammy Award for Record of the Year, Type: class of award
# Freebase ID: /m/01w61th, Entity: Ricky Martin, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0gx_st, Entity: 58th Primetime Emmy Awards, Type: Primetime Emmy Award annual ceremony
# Freebase ID: /m/09qvf4, Entity: Primetime Emmy Award for Outstanding Guest Actress in a Comedy Series, Type: class of award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09c7w0, Entity: United States of America, Type: country
# Freebase ID: /m/0rs6x, Entity: St. Augustine, Type: city in the United States
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/079vf, Entity: Stan Lee, Type: human
# Freebase ID: /m/0d90m, Entity: X-Men, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/015zyd, Entity: California Institute of the Arts, Type: film school
# Freebase ID: /m/05vsxz, Entity: Chiwetel Ejiofor, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06qgvf, Entity: Carla Gugino, Type: human
# Freebase ID: /m/04ljl_l, Entity: Golden Raspberry Award for Worst Supporting Actor, Type: Golden Raspberry Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03qcfvw, Entity: G.I. Joe: The Rise of Cobra, Type: film
# Freebase ID: /m/0grwj, Entity: Oprah Winfrey, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05sxg2, Entity: theatrical producer, Type: profession
# Freebase ID: /m/02ynfr, Entity: art director, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0bmch_x, Entity: Unknown, Type: film
# Freebase ID: /m/018gz8, Entity: comedian, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/071wvh, Entity: Brahmanandam, Type: human
# Freebase ID: /m/02cqbx, Entity: Edith Head, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01jr4j, Entity: Topaz, Type: film
# Freebase ID: /m/0rh6k, Entity: Washington, D.C., Type: capital city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01lp8, Entity: Christianity, Type: major religion
# Freebase ID: /m/03mqtr, Entity: political drama, Type: film genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04j4tx, Entity: The Killing Fields, Type: film
# No data found for Freebase ID: /m/01z4y
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07zhjj, Entity: How I Met Your Mother, Type: television series
# Freebase ID: /m/05d7rk, Entity: Saeed Jaffrey, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/027dtxw, Entity: BAFTA Award for Best Actor in a Supporting Role, Type: British Academy Film Awards
# Freebase ID: /m/05hs4r, Entity: heartland rock, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01pbxb, Entity: Bob Seger, Type: human
# Freebase ID: /m/03qcq, Entity: Hunter S. Thompson, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/084w8, Entity: William Faulkner, Type: human
# Freebase ID: /m/01lxd4, Entity: avant-garde jazz, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0f0y8, Entity: John Coltrane, Type: human
# Freebase ID: /m/08815, Entity: Yale University, Type: private university
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05bnp0, Entity: James Franco, Type: human
# Freebase ID: /m/08nhfc1, Entity: Crazy Heart, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/015c4g, Entity: Robert Duvall, Type: human
# Freebase ID: /m/0g56t9t, Entity: Frankenweenie, Type: 3D film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/062zm5h, Entity: The Avengers, Type: film
# Freebase ID: /m/0c9xjl, Entity: Clark Gregg, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0160w, Entity: The Bahamas, Type: country
# Freebase ID: /m/0dbpyd, Entity: Alan Burnett, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/053y0s, Entity: Bill Payne, Type: human
# Freebase ID: /m/0dz3r, Entity: record producer, Type: musical profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/016qtt, Entity: Billy Ray Cyrus, Type: human
# No data found for Freebase ID: /m/08mbj5d
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0b005, Entity: The Muppet Show, Type: television series
# Freebase ID: /m/07c52, Entity: television, Type: infrastructure
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/023wyl, Entity: cornerback, Type: American football position
# Freebase ID: /m/02wvfxl, Entity: Boston College Eagles football, Type: American football team
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09sh8k, Entity: Fantastic Four: Rise of the Silver Surfer, Type: film
# Freebase ID: /m/09zzb8, Entity: make-up artist, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05pd94v, Entity: 52nd Annual Grammy Awards, Type: award ceremony
# Freebase ID: /m/01vvydl, Entity: Dr. Dre, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0gtsx8c, Entity: American Reunion, Type: film
# Freebase ID: /m/0jgd, Entity: Argentina, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02r0csl, Entity: BAFTA Award for Best Makeup and Hair, Type: British Academy Film Awards
# Freebase ID: /m/0m313, Entity: Shakespeare in Love, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02y_lrp, Entity: The Love Guru, Type: film
# Freebase ID: /m/012d40, Entity: Jackie Chan, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/034qmv, Entity: Around the World in 80 Days, Type: feature film
# Freebase ID: /m/07rlg, Entity: triathlon, Type: type of sport
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0b90_r, Entity: Mexico, Type: country
# Freebase ID: /m/0g22z, Entity: Wall Street, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05b4l5x, Entity: Golden Raspberry Award for Worst Supporting Actress, Type: Golden Raspberry Awards
# Freebase ID: /m/018js4, Entity: Top Gun, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07fq1y, Entity: Rosemary Harris, Type: human
# Freebase ID: /m/02qgqt, Entity: Philip Seymour Hoffman, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/081jbk, Entity: Hilary Haag, Type: human
# Freebase ID: /m/02v5xg, Entity: RahXephon, Type: anime television series
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/028q6, Entity: Dave Brubeck, Type: human
# Freebase ID: /m/02581q, Entity: Grammy Award for Best Classical Crossover Album, Type: class of award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0sxg4, Entity: The Dresser, Type: film
# Freebase ID: /m/04xvlr, Entity: historical drama, Type: fiction genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02gpkt, Entity: Rush Hour, Type: film
# Freebase ID: /m/0fvf9q, Entity: Scott Rudin, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0l6qt, Entity: Alan Bennett, Type: human
# Freebase ID: /m/07jnt, Entity: The Shawshank Redemption, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0gq9h, Entity: Academy Award for Best Picture, Type: Academy Awards
# Freebase ID: /m/0jz9f, Entity: Miramax, Type: film distributor
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/083shs, Entity: The Cider House Rules, Type: film
# Freebase ID: /m/0njvn, Entity: Berrien County, Type: county of Michigan
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09nqf, Entity: United States dollar, Type: currency
# Freebase ID: /m/0d1tm, Entity: eventing, Type: Olympic sport
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0154j, Entity: Belgium, Type: country
# Freebase ID: /m/01br2w, Entity: The Passion of the Christ, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0kq0q, Entity: Calaveras County, Type: county of California
# Freebase ID: /m/03rl1g, Entity: 32nd United States Congress, Type: legislative term
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05kkh, Entity: Ohio, Type: U.S. state
# Freebase ID: /m/0fbq2n, Entity: Oregon Ducks football, Type: American football team
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01r3hr, Entity: running back, Type: American football position
# Freebase ID: /m/060bp, Entity: prime minister, Type: position
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/027nb, Entity: Dominica, Type: country
# Freebase ID: /m/04qvl7, Entity: Roger Deakins, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02vxq9m, Entity: Skyfall, Type: film
# Freebase ID: /m/04yywz, Entity: Burt Young, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0140g4, Entity: Rocky V, Type: film
# Freebase ID: /m/01k7d9, Entity: Ray Walston, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0k049, Entity: Beverly Hills, Type: city in the United States
# Freebase ID: /m/02p65p, Entity: Don Cheadle, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0337vz, Entity: Larenz Tate, Type: human
# Freebase ID: /m/06688p, Entity: John Barrowman, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0b2v79, Entity: The Untouchables, Type: film
# Freebase ID: /m/01c0cc, Entity: Technical University of Berlin, Type: institute of technology
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01jc6q, Entity: Cabaret, Type: film
# Freebase ID: /m/040njc, Entity: BAFTA Award for Best Film, Type: British Academy Film Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01wmjkb, Entity: Steven Tyler, Type: human
# Freebase ID: /m/0l14j_, Entity: flute, Type: type of musical instrument
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0520r2x, Entity: Richard Day, Type: human
# Freebase ID: /m/0cb77r, Entity: Thomas Little, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06j0md, Entity: James Burrows, Type: human
# Freebase ID: /m/05mgj0, Entity: UK Film Council, Type: organization
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0ds6bmk, Entity: Tyrannosaur, Type: film
# Freebase ID: /m/05b3ts, Entity: safety, Type: American football position
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0g2hw4, Entity: Oregon State Beavers football, Type: American football team
# Freebase ID: /m/0ktpx, Entity: Spellbound, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0hqcy, Entity: David O. Selznick, Type: human
# Freebase ID: /m/01453, Entity: ACF Fiorentina, Type: association football club
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0dgrmp, Entity: goalkeeper, Type: association football position
# Freebase ID: /m/028_yv, Entity: Once Upon a Time in America, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03rjj, Entity: Italy, Type: country
# Freebase ID: /m/01914, Entity: Beijing, Type: city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0bpbhm, Entity: Cookie's Fortune, Type: film
# Freebase ID: /m/0219x_, Entity: independent film, Type: film genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05_6_y, Entity: David Healy, Type: human
# Freebase ID: /m/02b15h, Entity: Doncaster Rovers F.C., Type: association football club
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0487c3, Entity: Jason Roberts, Type: human
# Freebase ID: /m/01j_jh, Entity: Bristol Rovers F.C., Type: association football club
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03c7ln, Entity: Jay Bennett, Type: human
# Freebase ID: /m/026t6, Entity: drum, Type: family of musical instruments
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01qvcr, Entity: Rare Ltd., Type: video game developer
# Freebase ID: /m/04sv4, Entity: Microsoft, Type: public company
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02pprs, Entity: alto saxophone, Type: musical instrument
# Freebase ID: /m/07s3vqk, Entity: Ray Charles, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0d05q4, Entity: Iraq, Type: country
# Freebase ID: /m/0784z, Entity: Six-Day War, Type: war
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0kwgs, Entity: Madison County, Type: county of Alabama
# Freebase ID: /m/0gyh, Entity: Alabama, Type: U.S. state
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01gbbz, Entity: Ellen DeGeneres, Type: human
# Freebase ID: /m/035ktt, Entity: University of New Orleans, Type: university
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05zjtn4, Entity: University of North Texas, Type: public educational institution of the United States
# Freebase ID: /m/0197tq, Entity: Norah Jones, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02_fm2, Entity: Treasure Planet, Type: animated feature film
# Freebase ID: /m/02x73k6, Entity: National Society of Film Critics Award for Best Supporting Actor, Type: National Society of Film Critics Award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02lxrv, Entity: Ed Wood, Type: film
# Freebase ID: /m/0411q, Entity: John Lee Hooker, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/016z4k, Entity: singer-songwriter, Type: occupation
# Freebase ID: /m/06151l, Entity: Freddy Rodriguez, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06gp3f, Entity: Justina Machado, Type: human
# Freebase ID: /m/01fq7, Entity: Battle Creek, Type: city in the United States
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06w99h3, Entity: Rango, Type: animated feature film
# Freebase ID: /m/02kdv5l, Entity: action film, Type: film genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05cljf, Entity: Keith Urban, Type: human
# Freebase ID: /m/08r4x3, Entity: Bobby, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03_6y, Entity: Joshua Jackson, Type: human
# Freebase ID: /m/0342h, Entity: guitar, Type: type of musical instrument
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0l14qv, Entity: synthesizer, Type: type of musical instrument
# Freebase ID: /m/02bfmn, Entity: Brad Dourif, Type: human
# Freebase ID: /m/05zppz, Entity: male organism, Type: biological sex
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/01rk91
# Freebase ID: /m/0kc6x, Entity: ESPN, Type: specialty channel
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01xdf5, Entity: Stephen Colbert, Type: human
# Freebase ID: /m/04t2l2, Entity: Steve Carell, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02rc4d, Entity: Goku, Type: film character
# Freebase ID: /m/0g0vx, Entity: farmer, Type: occupation
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/027qgy, Entity: My Big Fat Greek Wedding, Type: film
# Freebase ID: /m/06cvj, Entity: romantic comedy, Type: fiction genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01mkq, Entity: computer science, Type: academic major
# Freebase ID: /m/011xy1, Entity: Trinity College Dublin, Type: collegiate university
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0dxtw, Entity: special effects, Type: cinematic technique
# Freebase ID: /m/0cq86w, Entity: Oliver!, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02v8kmz, Entity: Bulworth, Type: film
# Freebase ID: /m/01j5ts, Entity: Anjelica Huston, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06_kh, Entity: Santa Monica, Type: city in the United States
# Freebase ID: /m/02hrh1q, Entity: actor, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01pcz9, Entity: Portia de Rossi, Type: human
# Freebase ID: /m/0dwl2, Entity: Valve Corporation, Type: video game developer
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01mw1, Entity: video game, Type: software category
# Freebase ID: /m/02wh75, Entity: Grammy Award for Best Rock Song, Type: Grammy Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0lbj1, Entity: Sting, Type: human
# Freebase ID: /m/0c3ybss, Entity: Insidious, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03cfjg, Entity: Marty Stuart, Type: human
# Freebase ID: /m/0jzphpx, Entity: 1994 Grammy Awards, Type: award ceremony
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06wxw, Entity: St. Louis, Type: city in the United States
# Freebase ID: /m/0jbk9, Entity: United States Department of Housing and Urban Development, Type: United States federal executive department
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0np9r, Entity: voice actor, Type: profession
# Freebase ID: /m/05bp8g, Entity: Kaneto Shiozawa, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01l1b90, Entity: Tyrese Gibson, Type: human
# Freebase ID: /m/0p07l, Entity: El Paso County, Type: county of Colorado
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01vsl, Entity: Colorado Springs, Type: city in the United States
# Freebase ID: /m/02vp1f_, Entity: Quest for Fire, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03_3d, Entity: Japan, Type: country
# Freebase ID: /m/060__y, Entity: film based on literature, Type: film genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03rtz1, Entity: North, Type: film
# Freebase ID: /m/09m6kg, Entity: A Beautiful Mind, Type: film
# Freebase ID: /m/02h40lc, Entity: English, Type: natural language
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/047q2k1, Entity: 3 Idiots, Type: film
# Freebase ID: /m/05p553, Entity: comedy, Type: genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01ypc, Entity: Cincinnati Reds, Type: baseball team
# Freebase ID: /m/02dwn9, Entity: starting pitcher, Type: baseball position
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01k_0fp, Entity: Roger Daltrey, Type: human
# Freebase ID: /m/0m77m, Entity: Doris Lessing, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02_h0, Entity: feminism, Type: ideology
# Freebase ID: /m/06dv3, Entity: Russell Crowe, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01rtm4, Entity: Sarah Lawrence College, Type: liberal arts college in the United States
# Freebase ID: /m/02rchht, Entity: Jon Avnet, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0dq3c, Entity: vice president, Type: position
# Freebase ID: /m/02zs4, Entity: Ford Motor Company, Type: holding company
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0qcr0, Entity: cancer, Type: class of disease
# Freebase ID: /m/0byfz, Entity: Laurence Olivier, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06wzvr, Entity: Can't Stop the Music, Type: film
# No data found for Freebase ID: /m/01q03
# Freebase ID: /m/01qn7n, Entity: The O.C., Type: television series
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/016tw3, Entity: Universal Pictures, Type: organization
# Freebase ID: /m/03tps5, Entity: Meet the Fockers, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0cnl80, Entity: Phyllis Smith, Type: human
# Freebase ID: /m/083chw, Entity: Rainn Wilson, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0gq_v, Entity: Academy Award for Best Production Design, Type: Academy Awards
# Freebase ID: /m/0k2cb, Entity: Dangerous Liaisons, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0qf43, Entity: Danny Boyle, Type: human
# Freebase ID: /m/0f_nbyh, Entity: Producers Guild of America Award for Best Theatrical Motion Picture, Type: Producers Guild of America Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0c0yh4, Entity: Sunshine, Type: film
# Freebase ID: /m/0d060g, Entity: Canada, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05qt0, Entity: politics, Type: academic discipline
# Freebase ID: /m/0nk72, Entity: Hannah Arendt, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01s3kv, Entity: Fran Drescher, Type: human
# Freebase ID: /m/03g90h, Entity: Babylon 5: The Gathering, Type: television film
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/02_n3z
# Freebase ID: /m/06cqb, Entity: reggae, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0827d, Entity: world music, Type: music genre
# Freebase ID: /m/02tkzn, Entity: Ed Asner, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/014zcr, Entity: George Clooney, Type: human
# Freebase ID: /m/05m63c, Entity: Krista Allen, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0yyg4, Entity: Mississippi Burning, Type: film
# Freebase ID: /m/027c924, Entity: National Board of Review Award for Best Director, Type: National Board of Review Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03f0324, Entity: Franz Kafka, Type: human
# Freebase ID: /m/040rjq, Entity: Martin McDonagh, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01tv3x2, Entity: Tim Armstrong, Type: human
# Freebase ID: /m/06rqw, Entity: ska, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0h3y, Entity: Algeria, Type: country
# Freebase ID: /m/0rtv, Entity: Algiers, Type: city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/090s_0, Entity: Gulliver's Travels, Type: miniseries
# Freebase ID: /m/0h0jz, Entity: Peter O'Toole, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05znxx, Entity: The Fugitive, Type: film
# Freebase ID: /m/02hsq3m, Entity: BAFTA Award for Best Special Visual Effects, Type: British Academy Film Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01kyvx, Entity: seiyū, Type: profession
# Freebase ID: /m/0ckr7s, Entity: Sailor Moon R: The Movie, Type: anime film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02ky346, Entity: engineering, Type: field of work
# Freebase ID: /m/0p5wz, Entity: University of Southampton, Type: higher education institution
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05ztjjw, Entity: MTV Movie Award for Best Movie, Type: MTV Movie & TV Awards
# Freebase ID: /m/01gc7, Entity: Braveheart, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04j53, Entity: Liechtenstein, Type: country
# Freebase ID: /m/04h68j, Entity: James Wong, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01g3gq, Entity: Final Destination, Type: film
# Freebase ID: /m/01vw87c, Entity: Jon Bon Jovi, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01gbcf, Entity: math rock, Type: music genre
# Freebase ID: /m/016clz, Entity: alternative rock, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/011yrp, Entity: Life is Beautiful, Type: film
# Freebase ID: /m/0d0vqn, Entity: Sweden, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/049tjg, Entity: Van Johnson, Type: human
# Freebase ID: /m/05jf85, Entity: The Purple Rose of Cairo, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/046f25, Entity: Grenada national football team, Type: national association football team
# Freebase ID: /m/0d1swh, Entity: Craig Rocastle, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0b_fw, Entity: Anthony Quinn, Type: human
# Freebase ID: /m/04t36, Entity: musical film, Type: film genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/011yxg, Entity: Moulin Rouge!, Type: film
# Freebase ID: /m/05v38p, Entity: Chocolat, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03hkv_r, Entity: Writers Guild of America Award for Best Adapted Screenplay, Type: Writers Guild of America Award
# Freebase ID: /m/025twgf, Entity: Dr. No, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0clpml, Entity: James Bond, Type: book series
# Freebase ID: /m/0t015, Entity: Iowa City, Type: city in the United States
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0j1z8, Entity: United Arab Emirates, Type: country
# Freebase ID: /m/07t65, Entity: United Nations, Type: organization
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0162b, Entity: Bangladesh, Type: country
# Freebase ID: /m/0fnb4, Entity: Dhaka, Type: city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0hd7j, Entity: University of Mississippi, Type: public university
# Freebase ID: /m/07xl34, Entity: chancellor, Type: job title
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02sgy, Entity: electric guitar, Type: type of musical instrument
# Freebase ID: /m/0l14md, Entity: percussion instrument, Type: family of musical instruments
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/05r5c
# Freebase ID: /m/0c9d9, Entity: Jean-Michel Jarre, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02g8h, Entity: Denis Leary, Type: human
# Freebase ID: /m/01d_h8, Entity: film producer, Type: filmmaking occupation
# Freebase ID: /m/0c_j9x, Entity: Murder on the Orient Express, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0n5j_, Entity: Bergen County, Type: county of New Jersey
# Freebase ID: /m/0fm9_, Entity: Rockland County, Type: county of New York
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04cy8rb, Entity: Conrad Buff IV, Type: human
# Freebase ID: /m/07gp9, Entity: Terminator 2: Judgment Day, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/081pw, Entity: World War II, Type: world war
# Freebase ID: /m/0gzy02, Entity: The Guns of Navarone, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05g8ky, Entity: Josh Schwartz, Type: human
# Freebase ID: /m/026wp, Entity: democracy, Type: form of state
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/049nq, Entity: Kingdom of the Netherlands, Type: country
# Freebase ID: /m/03t5kl, Entity: Grammy Award for Best Melodic Rap Performance, Type: Grammy Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01f2q5, Entity: The Roots, Type: musical group
# Freebase ID: /m/01jssp, Entity: University of Pittsburgh, Type: public–private partnership
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01l849, Entity: gold, Type: color
# Freebase ID: /m/0f4y_, Entity: Delaware County, Type: county of New York
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/08959, Entity: Zachary Taylor, Type: human
# Freebase ID: /m/0789n, Entity: secretary of state, Type: position
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01fkr_, Entity: VH1 USA, Type: specialty channel
# Freebase ID: /m/0mdxd, Entity: music video, Type: type of cinematic work
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03x3qv, Entity: Joshua Malina, Type: human
# Freebase ID: /m/0g60z, Entity: The West Wing, Type: television series
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0d_84, Entity: Val Kilmer, Type: human
# Freebase ID: /m/01hr1, Entity: Batman Forever, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/042l3v, Entity: Herbert Ross, Type: human
# Freebase ID: /m/026mg3, Entity: Grammy Award for Best Country Instrumental Performance, Type: class of award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01s695, Entity: 42nd Annual Grammy Awards, Type: award ceremony
# Freebase ID: /m/0gtt5fb, Entity: The Great Gatsby, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0tj9, Entity: Amitabh Bachchan, Type: human
# Freebase ID: /m/0hx4y, Entity: Jurassic Park, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01y_px, Entity: Jeff Goldblum, Type: human
# Freebase ID: /m/0k611, Entity: Academy Award for Best Film Editing, Type: Academy Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0hsmh, Entity: Robert Wise, Type: human
# Freebase ID: /m/0gx1bnj, Entity: Seeking a Friend for the End of the World, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04gzd, Entity: Lithuania, Type: country
# Freebase ID: /m/04njml, Entity: Tony Award for Best Original Score, Type: theatre award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07hgkd, Entity: David Shire, Type: human
# No data found for Freebase ID: /m/060c4
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04wlz2, Entity: Hampton University, Type: university
# Freebase ID: /m/01531, Entity: The Bronx, Type: borough of New York City
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0b1f49, Entity: Brad Grey, Type: human
# Freebase ID: /m/01gxqf, Entity: Macclesfield Town F.C., Type: defunct association football club
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01_qc_, Entity: pancreatic cancer, Type: class of disease
# No data found for Freebase ID: /m/0g5lhl7
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0c55fj, Entity: BBC HD, Type: television channel
# Freebase ID: /m/09xbpt, Entity: Ocean's Thirteen, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0yxl, Entity: Alan Moore, Type: human
# Freebase ID: /m/02w7gg, Entity: English people, Type: nation
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05f4m9q, Entity: Golden Raspberry Award for Worst Director, Type: Golden Raspberry Awards
# Freebase ID: /m/08lr6s, Entity: The Scarlet Letter, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09y20, Entity: Alan Rickman, Type: human
# Freebase ID: /m/01nrnm, Entity: Royal College of Art, Type: higher education institution
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0hl3d, Entity: Pierre Boulez, Type: human
# Freebase ID: /m/0cbd2, Entity: writer, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0495ys, Entity: 93rd United States Congress, Type: legislative term
# Freebase ID: /m/05l2z4, Entity: 90th United States Congress, Type: legislative term
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/018wrk, Entity: 1904 Summer Olympics, Type: Summer Olympic Games
# Freebase ID: /m/02bkg, Entity: diving, Type: type of sport
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0h5f5n, Entity: Peter Morgan, Type: human
# Freebase ID: /m/04jpl, Entity: London, Type: city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/047gn4y, Entity: Prince of Persia: The Sands of Time, Type: feature film
# Freebase ID: /m/05ty4m, Entity: Judd Apatow, Type: human
# Freebase ID: /m/0bvn25, Entity: Knocked Up, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/026p4q7, Entity: The Curious Case of Benjamin Button, Type: film
# Freebase ID: /m/044lyq, Entity: Jared Harris, Type: human
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/08mbj32
# Freebase ID: /m/01vs5c, Entity: University of Oklahoma, Type: public educational institution of the United States
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09jvl, Entity: NOFX, Type: musical group
# Freebase ID: /m/01g888, Entity: ska punk, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01vrx3g, Entity: Levon Helm, Type: human
# Freebase ID: /m/01lmj3q, Entity: Ricky Skaggs, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0m27n, Entity: Maricopa County, Type: county of Arizona
# Freebase ID: /m/0qpjt, Entity: Chandler, Type: city in the United States
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01c8w0, Entity: conducting, Type: activity
# Freebase ID: /m/023361, Entity: Jerry Goldsmith, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01qbg5, Entity: Gia, Type: film
# Freebase ID: /m/017fp, Entity: biography, Type: literary genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01gsvb, Entity: 18th United States Congress, Type: legislative term
# Freebase ID: /m/0b3wk, Entity: United States House of Representatives, Type: jurisdiction
# Freebase ID: /m/01wbg84, Entity: Steve Buscemi, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01r42_g, Entity: Jamie-Lynn Sigler, Type: human
# Freebase ID: /m/0gr51, Entity: Academy Award for Best Writing, Original Screenplay, Type: Academy Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04gcd1, Entity: Brad Bird, Type: human
# Freebase ID: /m/0ddfwj1, Entity: Submarine, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0sv6n, Entity: Burlington, Type: county seat
# Freebase ID: /m/02wkmx, Entity: Palme d'Or, Type: Cannes Film Festival Awards
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/02vxn
# Freebase ID: /m/0f5hyg, Entity: Granada CF, Type: association football club
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0126y2, Entity: Ja Rule, Type: human
# Freebase ID: /m/01flzq, Entity: hardcore hip hop, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05cj4r, Entity: Eileen Atkins, Type: human
# Freebase ID: /m/0bfvw2, Entity: Primetime Emmy Award for Outstanding Supporting Actress in a Miniseries or a Movie, Type: Primetime Emmy Award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/023tp8, Entity: Patricia Arquette, Type: human
# Freebase ID: /m/0dq626, Entity: Holes, Type: feature film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07sbbz2, Entity: rock and roll, Type: music genre
# Freebase ID: /m/089tm, Entity: ZZ Top, Type: musical group
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0m2wm, Entity: Claudia Schiffer, Type: human
# Freebase ID: /m/02zq43, Entity: Thomas Brodie-Sangster, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/086k8, Entity: Warner Bros., Type: film production company
# Freebase ID: /m/0czyxs, Entity: Watchmen, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/014635, Entity: Mark Twain, Type: human
# Freebase ID: /m/02kz_, Entity: Ernest Hemingway, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0ds3t5x, Entity: The Help, Type: film
# Freebase ID: /m/02896, Entity: Dallas Cowboys, Type: American football team
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05krk, Entity: Ohio State University, Type: land-grant university
# Freebase ID: /m/0chghy, Entity: Australia, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0l6vl, Entity: 1980 Summer Olympics, Type: Summer Olympic Games
# Freebase ID: /m/02tcgh, Entity: Kal Ho Naa Ho, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0kvgnq, Entity: The Unbearable Lightness of Being, Type: film
# Freebase ID: /m/02x4wr9, Entity: Independent Spirit Award for Best Director, Type: Independent Spirit Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/017z49, Entity: Memento, Type: film
# Freebase ID: /m/08p1gp, Entity: Luci Christian, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0dnvn3, Entity: The Ladykillers, Type: film
# Freebase ID: /m/07zrf, Entity: Vietnamese, Type: language
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/016fyc, Entity: The Usual Suspects, Type: film
# Freebase ID: /m/01qscs, Entity: Benicio del Toro, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01p7yb, Entity: Frances McDormand, Type: human
# Freebase ID: /m/0p_pd, Entity: Bill Murray, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0bl2g, Entity: Dustin Hoffman, Type: human
# Freebase ID: /m/0prfz, Entity: Liev Schreiber, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02pw_n, Entity: Garden State, Type: film
# Freebase ID: /m/09l3p, Entity: Natalie Portman, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0k9ctht, Entity: RKO Pictures, Type: film distributor
# Freebase ID: /m/0fr63l, Entity: Mighty Joe Young, Type: feature film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01q_ph, Entity: Owen Wilson, Type: human
# Freebase ID: /m/05zr6wv, Entity: MTV Movie Award for Best On-Screen Duo, Type: MTV Movie & TV Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0cjk9, Entity: Ukrainian, Type: language
# Freebase ID: /m/047lj, Entity: Kazakhstan, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0s3y5, Entity: Urbana, Type: county seat
# Freebase ID: /m/09fb5, Entity: Jack Nicholson, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07xtqq, Entity: One Flew Over the Cuckoo's Nest, Type: film
# Freebase ID: /m/05hcy, Entity: Nassau, Type: city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0jg1q, Entity: House of Orange-Nassau, Type: dynasty
# Freebase ID: /m/0c5lg, Entity: judge, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0rlz, Entity: Andrew Jackson, Type: human
# Freebase ID: /m/02ktt7, Entity: Kraft Foods Group, Type: public company
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/03w5xm
# Freebase ID: /m/026v437, Entity: Paz de la Huerta, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/080dwhx, Entity: Boardwalk Empire, Type: television series
# Freebase ID: /m/0150jk, Entity: Nickelback, Type: rock band
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05bt6j, Entity: pop rock, Type: music genre
# Freebase ID: /m/01k1k4, Entity: Austin Powers: The Spy Who Shagged Me, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09gq0x5, Entity: The King's Speech, Type: film
# Freebase ID: /m/0gtv7pk, Entity: Resident Evil: Retribution, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01ls2, Entity: Colombia, Type: country
# Freebase ID: /m/02rbdlq, Entity: Scottish Canadians, Type: ethnic group
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0l8v5, Entity: Neve Campbell, Type: human
# Freebase ID: /m/095zlp, Entity: The Hours, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06q2q, Entity: scientist, Type: profession
# Freebase ID: /m/0hnws, Entity: Iron Man, Type: comics character
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09wj5, Entity: Orlando Bloom, Type: human
# Freebase ID: /m/0m4yg, Entity: Guildhall School of Music and Drama, Type: university
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09c7b, Entity: Metropolitan Museum of Art, Type: art museum
# Freebase ID: /m/0hhbr, Entity: art museum, Type: type of museum
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03ckxdg, Entity: Elizabeth Page, Type: human
# Freebase ID: /m/02_1q9, Entity: Another World, Type: television series
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09n48, Entity: 2002 Winter Olympics, Type: Winter Olympic Games
# Freebase ID: /m/020qr4, Entity: Sonic X, Type: anime television series
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03_r3, Entity: Jamaica, Type: country
# Freebase ID: /m/02lq67, Entity: bronze medal, Type: medallion
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0fvwg, Entity: Annapolis, Type: county seat
# Freebase ID: /m/0dtw1x, Entity: The Aristocrats, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01yznp, Entity: Penn Jillette, Type: human
# Freebase ID: /m/01tvz5j, Entity: Maria Bello, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03rs8y, Entity: Eriq La Salle, Type: human
# Freebase ID: /m/0h1cdwq, Entity: Alvin and the Chipmunks: Chipwrecked, Type: feature film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03rt9, Entity: Republic of Ireland, Type: country
# Freebase ID: /m/0m2kd, Entity: Stand by Me, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0jdk_, Entity: 2000 Summer Olympics, Type: Summer Olympic Games
# Freebase ID: /m/064vjs, Entity: canoe sprint, Type: sports discipline
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/042v_gx
# Freebase ID: /m/025cbm, Entity: clavinet, Type: musical instrument model
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03qbh5, Entity: Grammy Award for Best Pop Collaboration with Vocals, Type: Grammy Awards
# Freebase ID: /m/09hnb, Entity: Herbie Hancock, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/052q4j, Entity: Catholic school, Type: type of educational institution
# Freebase ID: /m/01fxg8, Entity: Pontifical Gregorian University, Type: pontifical university
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0146pg, Entity: John Williams, Type: human
# Freebase ID: /m/0bzjvm, Entity: 48th Academy Awards, Type: Academy Awards ceremony
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0cj_v7, Entity: Derby County F.C., Type: association football club
# Freebase ID: /m/0jt90f5, Entity: Stephen King, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/067xw, Entity: Peter David, Type: human
# Freebase ID: /m/025h4z, Entity: Judd Hirsch, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0bp_b2, Entity: Primetime Emmy Award for Outstanding Guest Actor in a Drama Series, Type: Primetime Emmy Award
# Freebase ID: /m/02fqrf, Entity: Batman Begins, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/057xs89, Entity: MTV Movie Award for Best Villain, Type: MTV Movie & TV Awards
# Freebase ID: /m/05y7hc, Entity: Craig Armstrong, Type: human
# Freebase ID: /m/01g0p5, Entity: Royal Academy of Music, Type: university
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/032xhg, Entity: Jason Bateman, Type: human
# Freebase ID: /m/034qrh, Entity: DodgeBall: A True Underdog Story, Type: film
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/050023, Entity: Richard Culliton, Type: human
# Freebase ID: /m/026dcvf, Entity: Christopher Whitesell, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0195fx, Entity: rapid transit, Type: train and rail category
# Freebase ID: /m/0m_sb, Entity: Northern line, Type: rapid transit railway line
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/023rwm, Entity: Roadrunner Records, Type: record label
# Freebase ID: /m/01t_xp_, Entity: Rush, Type: rock band
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/021gt5, Entity: Litchfield, Type: county seat
# Freebase ID: /m/01dw4q, Entity: Teri Hatcher, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02qjj7, Entity: Dean Cain, Type: human
# Freebase ID: /m/0436f4, Entity: Vincent Pastore, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02lfcm, Entity: Michael Imperioli, Type: human
# Freebase ID: /m/024jwt, Entity: Henry Winkler, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03v1s, Entity: Indiana, Type: U.S. state
# Freebase ID: /m/0plyy, Entity: Terre Haute, Type: county seat
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0z4s, Entity: Anthony Hopkins, Type: human
# Freebase ID: /m/099jhq, Entity: Broadcast Film Critics Association Award for Best Supporting Actor, Type: Critics' Choice Movie Award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0sx7r, Entity: 1992 Winter Olympics, Type: Winter Olympic Games
# Freebase ID: /m/03tmr, Entity: ice hockey, Type: type of sport
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02j9z, Entity: Europe, Type: continent
# Freebase ID: /m/05qhw, Entity: Poland, Type: country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0h1_w, Entity: Fredric March, Type: human
# Freebase ID: /m/0789_m, Entity: Tony Award for Best Actor in a Play, Type: theatre award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/054_mz, Entity: Lawrence Bender, Type: human
# Freebase ID: /m/039n1, Entity: Georg Wilhelm Friedrich Hegel, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/099bk, Entity: Martin Heidegger, Type: human
# Freebase ID: /m/05qd_, Entity: Paramount Pictures, Type: film production company
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0jsf6, Entity: The Godfather Part II, Type: film
# Freebase ID: /m/0fp_v1x, Entity: Stewart Copeland, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09bjv, Entity: Beirut, Type: capital city
# Freebase ID: /m/05zkcn5, Entity: MTV Movie Award for Best Song from a Movie, Type: MTV Movie & TV Awards
# ...
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0cfs8, Entity: cathedral, Type: building type
# Freebase ID: /m/0qdzd, Entity: B movie, Type: film genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/024h08, Entity: Indonesian cuisine, Type: national cuisine
# Freebase ID: /m/0pybl, Entity: Expressionism, Type: art of painting
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/027hljt, Entity: Central Alberta, Type: geographic region
# Freebase ID: /m/013_5c, Entity: New Zealand Labour Party, Type: political party
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/047f9jp, Entity: Jagdish Raj, Type: human
# Freebase ID: /m/0g6pl, Entity: Art Nouveau, Type: architectural style
# Freebase ID: /m/07yqn, Entity: platform game, Type: video game genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02r20ff, Entity: Out of Iraq Caucus, Type: congressional caucus
# Freebase ID: /m/0fgsq2, Entity: art dealer, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/018lc_, Entity: Niagara Falls, Type: city
# Freebase ID: /m/066d03, Entity: deathcore, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05frqx, Entity: Toronto District School Board, Type: academic institution
# Freebase ID: /m/01rww3, Entity: K Records, Type: record label
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0gyvgw, Entity: Wigan, Type: town
# Freebase ID: /m/022tzk, Entity: Palomar Mountain Observatory, Type: astronomical observatory
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0140xf, Entity: Christmas music, Type: music genre
# Freebase ID: /m/01sfl, Entity: clown, Type: circus profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02049g, Entity: Carmarthen, Type: community
# Freebase ID: /m/01nbk4, Entity: Communist Party of Germany, Type: communist party
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/06cvx, Entity: Renaissance, Type: art movement
# Freebase ID: /m/0x2gl, Entity: manslaughter, Type: manner of death
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01xq0k1, Entity: cattle, Type: organisms known by a particular common name
# Freebase ID: /m/02m30v, Entity: Joan Bennett, Type: human
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/022b_, Entity: Casablanca, Type: city
# Freebase ID: /m/06zfw, Entity: skateboarding, Type: type of sport
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01tlyq, Entity: Ontario Liberal Party, Type: political party
# Freebase ID: /m/01ld4n, Entity: Congregational churches, Type: Christian denominational family
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0hfp, Entity: Afroasiatic, Type: language family
# Freebase ID: /m/0mz2, Entity: alternate history, Type: speculative/fantastic fiction genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0kwr, Entity: Anglican Communion, Type: religious denomination
# Freebase ID: /m/01fhsb, Entity: pastor, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04gp3_2, Entity: This TV, Type: television station
# Freebase ID: /m/019rvp, Entity: Maidstone, Type: county town
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03y05ty, Entity: bubonic plague, Type: class of disease
# No data found for Freebase ID: /m/0dbtv
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01rng, Entity: County Mayo, Type: county of Ireland
# Freebase ID: /m/02_tw, Entity: Fine Gael, Type: political party
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0kff3, Entity: cougar, Type: taxon
# Freebase ID: /m/0145m, Entity: Afrobeat, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02p4l6s, Entity: African popular music, Type: music genre
# Freebase ID: /m/021lkq, Entity: Barnet, Type: area of London
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07619_, Entity: strongman, Type: profession
# Freebase ID: /m/0q245, Entity: Pre-Raphaelite Brotherhood, Type: art movement
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02l3gf, Entity: Victorian architecture, Type: architectural style
# Freebase ID: /m/0c_xl, Entity: statistician, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03_2f, Entity: igneous rock, Type: rock type
# Freebase ID: /m/0fq5j, Entity: Kuwait City, Type: city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/012k_9, Entity: Apache License, Type: software license
# Freebase ID: /m/03gkb0, Entity: socialite, Type: social class
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09wc5, Entity: Shiraz, Type: city of Iran
# Freebase ID: /m/0kcc7, Entity: cinema complex, Type: class
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0276bn, Entity: Peoples Democratic Party, Type: political party
# Freebase ID: /m/03ng8q, Entity: Vagrant Records, Type: record label
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01hg2h, Entity: Soviet Air Forces, Type: air force
# Freebase ID: /m/012xsy, Entity: music of Japan, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01_bhs, Entity: fast food, Type: industry
# Freebase ID: /m/01zxzp, Entity: psychological horror, Type: horror genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07yr3, Entity: fighting game, Type: video game genre
# Freebase ID: /m/025sh_8, Entity: Washington metropolitan area, Type: capital region
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0fqpg6b, Entity: AACTA Award for Best Guest or Supporting Actor in a Television Drama, Type: AACTA Awards
# Freebase ID: /m/07vzd, Entity: politics of the United States, Type: political system
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0g_tv, Entity: Montmartre Cemetery, Type: cemetery
# Freebase ID: /m/013rxq, Entity: tejano music, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/053f5, Entity: mountaineering, Type: type of sport
# Freebase ID: /m/08hbxv, Entity: Kosi Zone, Type: zone of Nepal
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/018hzk, Entity: cooking show, Type: television genre
# Freebase ID: /m/0gg81w, Entity: educational television, Type: television genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/04s84y, Entity: general contractor, Type: profession
# Freebase ID: /m/01_30_, Entity: Strategic Simulations, Type: video game developer
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01cgxp, Entity: Mosul, Type: city
# Freebase ID: /m/01l5rz, Entity: Grimsby, Type: town
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02qmjqd, Entity: 2001 Major League Baseball season, Type: sports season
# Freebase ID: /m/01773g, Entity: Stavanger, Type: municipality of Norway
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/026_51, Entity: Japanese mythology, Type: mythology
# Freebase ID: /m/0276krm, Entity: fawn, Type: color
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02mxx4, Entity: limited company, Type: legal form
# Freebase ID: /m/018s4, Entity: BSD licenses, Type: OSI-approved license
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05ws7, Entity: police, Type: government agency
# Freebase ID: /m/06w_b, Entity: structured programming, Type: programming paradigm
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02cjrp, Entity: bowler, Type: position
# Freebase ID: /m/02cmr1, Entity: all-rounder, Type: position
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01zjn0, Entity: Barrow-in-Furness, Type: town
# Freebase ID: /m/01zk9d, Entity: St Andrews, Type: town
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0190_8, Entity: Church of Scotland, Type: national Church
# Freebase ID: /m/01vpt5, Entity: Greater Houston, Type: metropolitan statistical area
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01vz08, Entity: Joseon, Type: historical country
# Freebase ID: /m/017ht, Entity: bhangra, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0x2jd, Entity: Supreme Court of Canada, Type: supreme court
# Freebase ID: /m/0fr_v, Entity: Paramaribo, Type: city
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/08x9pc, Entity: Imperial House of Japan, Type: dynasty
# Freebase ID: /m/050sw4, Entity: contemporary hit radio, Type: radio format
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0d2mh7, Entity: Bagrationi dynasty, Type: dynasty
# Freebase ID: /m/0mbx4, Entity: child actor, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02pyg, Entity: extreme sport, Type: type of sport
# Freebase ID: /m/015q02, Entity: Perak, Type: state of Malaysia
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0_678, Entity: tactical shooter, Type: video game genre
# No data found for Freebase ID: /m/026v1nw
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0259tnd, Entity: nonprofit organization, Type: industry
# Freebase ID: /m/02y_3rt, Entity: alpha carotene (stereochemistry specified), Type: type of chemical entity
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09dhj, Entity: family, Type: social organization
# Freebase ID: /m/027752, Entity: United National Party, Type: political party
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02y_93f, Entity: surgeon, Type: academic degree
# Freebase ID: /m/03m5x4, Entity: NBA Finals, Type: recurring sporting event
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01pwbn, Entity: true crime, Type: non-fiction genre
# Freebase ID: /m/02p0zzf, Entity: United States Army Air Corps, Type: military branch
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0blbx, Entity: Glasnevin Cemetery, Type: cemetery
# Freebase ID: /m/02g982, Entity: West Norwood Cemetery, Type: cemetery
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/022qqh, Entity: curator, Type: profession
# Freebase ID: /m/01t_1p, Entity: contemporary worship music, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05s0y9, Entity: United States House Committee on Financial Services, Type: United States congressional committee
# Freebase ID: /m/047vnfs, Entity: association football coach, Type: profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03ch14, Entity: television special, Type: form of television program
# No data found for Freebase ID: /m/01kd3m
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/024030, Entity: Padma Vibhushan, Type: award
# Freebase ID: /m/0gwj, Entity: autism, Type: disability
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0p8bz, Entity: Hamilton, Type: town
# No data found for Freebase ID: /m/01_6hg
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/09bv45, Entity: CITV, Type: specialty channel
# Freebase ID: /m/016zxr, Entity: Europop, Type: music genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05sz6, Entity: Provisional Irish Republican Army, Type: paramilitary organization
# Freebase ID: /m/01803s, Entity: immortality, Type: superpower
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02vq9j, Entity: hereditary peer, Type: position
# Freebase ID: /m/0bk25, Entity: Macedonia, Type: historical country
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01f99l, Entity: Bath Iron Works, Type: shipyard
# Freebase ID: /m/03f_jk, Entity: Lasker-DeBakey Clinical Medical Research Award, Type: science award
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/05my9, Entity: Orthodox Judaism, Type: Jewish religious movements
# Freebase ID: /m/01g4qq, Entity: philanthropy, Type: activity
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0cqbc, Entity: asteroid belt, Type: circumstellar disk
# Freebase ID: /m/0bwgmzd, Entity: AACTA Award for Best Telefeature, Mini Series or Short Run Series, Type: AACTA Awards
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0f69h, Entity: neo-Nazism, Type: social movement
# Freebase ID: /m/01qm7, Entity: community college, Type: type of educational institution
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07svc3, Entity: John Brown & Company, Type: business
# Freebase ID: /m/018zsw, Entity: Canadian Army, Type: army
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/050yl, Entity: military history, Type: academic major
# Freebase ID: /m/012wvj, Entity: Cumann na nGaedheal, Type: political party
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02wt_x, Entity: multivariable calculus, Type: area of mathematics
# Freebase ID: /m/05swd, Entity: propaganda film, Type: film genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/037vqt, Entity: James E. Sullivan Award, Type: sports award
# Freebase ID: /m/09ff3, Entity: Cubism, Type: architectural style
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02p4pt3, Entity: House of Plantagenet, Type: dynasty
# Freebase ID: /m/01mtt, Entity: card game, Type: game genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02y_9cf, Entity: Ethiopian Empire, Type: historical country
# Freebase ID: /m/068bs, Entity: primary school, Type: educational stage
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/03jjn8, Entity: Liberal Party of the Philippines, Type: political party
# Freebase ID: /m/01z645, Entity: Kettering, Type: town
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0k80c, Entity: real-time strategy, Type: video game genre
# Freebase ID: /m/034wx3, Entity: Brompton Cemetery, Type: cemetery
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0513yzt, Entity: ballet dancer, Type: profession
# Freebase ID: /m/02r8dcw, Entity: 1998 Major League Baseball season, Type: sports season
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0d8m3, Entity: Pulitzer Prize for History, Type: class of award
# Freebase ID: /m/01fm_, Entity: Social Democratic Party, Type: political party
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/014bmh, Entity: car bomb, Type: weapon functional class
# Freebase ID: /m/0fkv5, Entity: Cichlidae, Type: taxon
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02z3cm0, Entity: ECW Hardcore TV, Type: television series
# Freebase ID: /m/01g901, Entity: far-right, Type: political alignment
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0dlj8q2, Entity: Le Monde's 100 Books of the Century, Type: hall of fame
# Freebase ID: /m/046gm5, Entity: Borjigin, Type: dynasty
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/033th, Entity: first-person shooter, Type: video game genre
# Freebase ID: /m/01k12m, Entity: Dutch Golden Age, Type: golden age
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/01pvc5, Entity: jockey, Type: profession
# No data found for Freebase ID: /m/0f1f4k
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0fkrk, Entity: Poaceae, Type: taxon
# No data found for Freebase ID: /m/05cxb38
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02m97n, Entity: Vickers-Armstrongs, Type: business
# No data found for Freebase ID: /m/0kj0
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/0qb7t
# Freebase ID: /m/02kysg, Entity: students' union, Type: extracurricular activity
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/07068, Entity: samurai, Type: profession
# No data found for Freebase ID: /m/02jnw
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02070z, Entity: killed in action, Type: manner of death
# Freebase ID: /m/09hljw, Entity: tribal chief, Type: title
# Rate limited. Retrying in 1 seconds...
# No data found for Freebase ID: /m/02wv6th
# Freebase ID: /m/02h661t, Entity: dentist, Type: health profession
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/02r74mj, Entity: 1995 Major League Baseball season, Type: sports season
# Freebase ID: /m/03dfth, Entity: contemporary philosophy, Type: academic discipline
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0zq7r, Entity: Vertigo, Type: book publisher
# Freebase ID: /m/03ykjs9, Entity: comedy, Type: theatrical genre
# Rate limited. Retrying in 1 seconds...
# Freebase ID: /m/0194x, Entity: Baroque, Type: art movement
# Freebase ID: /m/04gbl3, Entity: Ocean Software, Type: video game developer
# Finished updating the dictionary with entity types.

# %%
entity_types = set()
for fb_id, info in FB15K_Updated.items():
    print(f"Freebase ID: {fb_id}")
    print(f"Entity Name: {info['entity_name']}")
    print(f"Entity Type: {info['entity_type']}")
    entity_types.add(info['entity_type'])
    print("---------------")
# Out:
# Freebase ID: /m/027rn
# Entity Name: Dominican Republic
# Entity Type: country
# ---------------
# Freebase ID: /m/06cx9
# Entity Name: republic
# Entity Type: form of state
# ---------------
# Freebase ID: /m/017dcd
# Entity Name: Mighty Morphin Power Rangers
# Entity Type: television series
# ---------------
# Freebase ID: /m/06v8s0
# Entity Name: Wendee Lee
# Entity Type: human
# ---------------
# Freebase ID: /m/07s9rl0
# Entity Name: drama film
# Entity Type: film genre
# ---------------
# Freebase ID: /m/0170z3
# Entity Name: American History X
# Entity Type: film
# ---------------
# Freebase ID: /m/01sl1q
# Entity Name: Michelle Rodriguez
# Entity Type: human
# ---------------
# Freebase ID: /m/044mz_
# Entity Name: Naveen Andrews
# Entity Type: human
# ---------------
# Freebase ID: /m/0cnk2q
# Entity Name: Australia men's national soccer team
# Entity Type: national association football team
# ---------------
# Freebase ID: /m/02nzb8
# Entity Name: midfielder
# Entity Type: association football position
# ---------------
# Freebase ID: /m/02_j1w
# Entity Name: defender
# Entity Type: association football position
# ---------------
# Freebase ID: /m/01cwm1
# Entity Name: Stoke City F.C.
# Entity Type: association football club
# ---------------
# Freebase ID: /m/059ts
# Entity Name: Northwest Territories
# Entity Type: territory of Canada
# ---------------
# Freebase ID: /m/03h_f4
# Entity Name: 34th Canadian Parliament
# Entity Type: term of the Canadian federal parliament
# ---------------
# Freebase ID: /m/011yn5
# Entity Name: As Good as It Gets
# Entity Type: film
# ---------------
# Freebase ID: /m/01pjr7
# Entity Name: Harold Ramis
# Entity Type: human
# ---------------
# Freebase ID: /m/04nrcg
# Entity Name: Maldives national football team
# Entity Type: national association football team
# ---------------
# Freebase ID: /m/02sdk9v
# Entity Name: forward
# Entity Type: association football position
# ---------------
# Freebase ID: /m/07nznf
# Entity Name: Bryan Singer
# Entity Type: human
# ---------------
# Freebase ID: /m/014lc_
# Entity Name: Star Trek: Nemesis
# Entity Type: film
# ---------------
# Freebase ID: /m/05cvgl
# Entity Name: The Remains of the Day
# Entity Type: film
# ---------------
# Freebase ID: /m/04kxsb
# Entity Name: BAFTA Award for Best Actor in a Leading Role
# Entity Type: British Academy Film Awards
# ---------------
# Freebase ID: /m/02qyp19
# Entity Name: BAFTA Award for Best Original Screenplay
# Entity Type: British Academy Film Awards
# ---------------
# Freebase ID: /m/02d413
# Entity Name: Philadelphia
# Entity Type: film
# ---------------
# Freebase ID: /m/02vk52z
# Entity Name: World Bank
# Entity Type: international financial institution
# ---------------
# Freebase ID: /m/01crd5
# Entity Name: Vietnam
# Entity Type: country
# ---------------
# Freebase ID: /m/0q9kd
# Entity Name: Danny DeVito
# Entity Type: human
# ---------------
# Freebase ID: /m/0184jc
# Entity Name: Guy Pearce
# Entity Type: human
# ---------------
# Freebase ID: /m/09w1n
# Entity Name: alpine skiing
# Entity Type: type of sport
# ---------------
# Freebase ID: /m/0sx8l
# Entity Name: 1980 Winter Olympics
# Entity Type: Winter Olympic Games
# ---------------
# Freebase ID: /m/07y_7
# Entity Name: violin
# Entity Type: type of musical instrument
# ---------------
# Freebase ID: /m/0gqng
# Entity Name: Academy Award for Best International Feature Film
# Entity Type: Academy Awards
# ---------------
# Freebase ID: /m/073hkh
# Entity Name: 61st Academy Awards
# Entity Type: Academy Awards ceremony
# ---------------
# Freebase ID: /m/0b76d_m
# Entity Name: Anonymous
# Entity Type: film
# ---------------
# Freebase ID: /m/029j_
# Entity Name: DVD
# Entity Type: physical media format
# ---------------
# Freebase ID: /m/04ztj
# Entity Name: marriage
# Entity Type: institution
# ---------------
# Freebase ID: /m/012v9y
# Entity Name: William Holden
# Entity Type: human
# ---------------
# Freebase ID: /m/014_x2
# Entity Name: City of Angels
# Entity Type: film
# ---------------
# Freebase ID: /m/012ljv
# Entity Name: Gabriel Yared
# Entity Type: human
# ---------------
# Freebase ID: /m/0ds35l9
# Entity Name: Bridesmaids
# Entity Type: film
# ---------------
# Freebase ID: /m/05r4w
# Entity Name: Portugal
# Entity Type: country
# ---------------
# Freebase ID: /m/015qsq
# Entity Name: Serpico
# Entity Type: film
# ---------------
# Freebase ID: /m/02bjrlw
# Entity Name: Italian
# Entity Type: language
# ---------------
# Freebase ID: /m/04bdxl
# Entity Name: Catherine Keener
# Entity Type: human
# ---------------
# Freebase ID: /m/02s2ft
# Entity Name: Chris Cooper
# Entity Type: human
# ---------------
# Freebase ID: /m/0677ng
# Entity Name: Swizz Beatz
# Entity Type: human
# ---------------
# Freebase ID: /m/03ckfl9
# Entity Name: experimental music
# Entity Type: music genre
# ---------------
# Freebase ID: /m/03zj9
# Entity Name: Ithaca College
# Entity Type: private university
# ---------------
# Freebase ID: /m/059rby
# Entity Name: New York
# Entity Type: U.S. state
# ---------------
# Freebase ID: /m/0157m
# Entity Name: Bill Clinton
# Entity Type: human
# ---------------
# Freebase ID: /m/063k3h
# Entity Name: Scotch-Irish Americans
# Entity Type: ethnic group
# ---------------
# Freebase ID: /m/01ky7c
# Entity Name: University of Massachusetts Amherst
# Entity Type: university
# ---------------
# Freebase ID: /m/019v9k
# Entity Name: bachelor's degree
# Entity Type: educational stage
# ---------------
# Freebase ID: /m/02681vq
# Entity Name: Latin Grammy Award for Record of the Year
# Entity Type: class of award
# ---------------
# Freebase ID: /m/01w61th
# Entity Name: Ricky Martin
# Entity Type: human
# ---------------
# Freebase ID: /m/0gx_st
# Entity Name: 58th Primetime Emmy Awards
# Entity Type: Primetime Emmy Award annual ceremony
# ---------------
# Freebase ID: /m/09qvf4
# Entity Name: Primetime Emmy Award for Outstanding Guest Actress in a Comedy Series
# Entity Type: class of award
# ---------------
# Freebase ID: /m/09c7w0
# Entity Name: United States of America
# Entity Type: country
# ---------------
# Freebase ID: /m/0rs6x
# Entity Name: St. Augustine
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/079vf
# Entity Name: Stan Lee
# Entity Type: human
# ---------------
# Freebase ID: /m/0d90m
# Entity Name: X-Men
# Entity Type: film
# ---------------
# Freebase ID: /m/015zyd
# Entity Name: California Institute of the Arts
# Entity Type: film school
# ---------------
# Freebase ID: /m/05vsxz
# Entity Name: Chiwetel Ejiofor
# Entity Type: human
# ---------------
# Freebase ID: /m/06qgvf
# Entity Name: Carla Gugino
# Entity Type: human
# ---------------
# Freebase ID: /m/04ljl_l
# Entity Name: Golden Raspberry Award for Worst Supporting Actor
# Entity Type: Golden Raspberry Awards
# ---------------
# Freebase ID: /m/03qcfvw
# Entity Name: G.I. Joe: The Rise of Cobra
# Entity Type: film
# ---------------
# Freebase ID: /m/0grwj
# Entity Name: Oprah Winfrey
# Entity Type: human
# ---------------
# Freebase ID: /m/05sxg2
# Entity Name: theatrical producer
# Entity Type: profession
# ---------------
# Freebase ID: /m/02ynfr
# Entity Name: art director
# Entity Type: profession
# ---------------
# Freebase ID: /m/0bmch_x
# Entity Name: Unknown
# Entity Type: film
# ---------------
# Freebase ID: /m/018gz8
# Entity Name: comedian
# Entity Type: profession
# ---------------
# Freebase ID: /m/071wvh
# Entity Name: Brahmanandam
# Entity Type: human
# ---------------
# Freebase ID: /m/02cqbx
# Entity Name: Edith Head
# Entity Type: human
# ---------------
# Freebase ID: /m/01jr4j
# Entity Name: Topaz
# Entity Type: film
# ---------------
# Freebase ID: /m/0rh6k
# Entity Name: Washington, D.C.
# Entity Type: capital city
# ---------------
# Freebase ID: /m/01lp8
# Entity Name: Christianity
# Entity Type: major religion
# ---------------
# Freebase ID: /m/03mqtr
# Entity Name: political drama
# Entity Type: film genre
# ---------------
# Freebase ID: /m/04j4tx
# Entity Name: The Killing Fields
# Entity Type: film
# ---------------
# Freebase ID: /m/07zhjj
# Entity Name: How I Met Your Mother
# Entity Type: television series
# ---------------
# Freebase ID: /m/05d7rk
# Entity Name: Saeed Jaffrey
# Entity Type: human
# ---------------
# Freebase ID: /m/027dtxw
# Entity Name: BAFTA Award for Best Actor in a Supporting Role
# Entity Type: British Academy Film Awards
# ---------------
# Freebase ID: /m/05hs4r
# Entity Name: heartland rock
# Entity Type: music genre
# ---------------
# Freebase ID: /m/01pbxb
# Entity Name: Bob Seger
# Entity Type: human
# ---------------
# Freebase ID: /m/03qcq
# Entity Name: Hunter S. Thompson
# Entity Type: human
# ---------------
# Freebase ID: /m/084w8
# Entity Name: William Faulkner
# Entity Type: human
# ---------------
# Freebase ID: /m/01lxd4
# Entity Name: avant-garde jazz
# Entity Type: music genre
# ---------------
# Freebase ID: /m/0f0y8
# Entity Name: John Coltrane
# Entity Type: human
# ---------------
# Freebase ID: /m/08815
# Entity Name: Yale University
# Entity Type: private university
# ---------------
# Freebase ID: /m/05bnp0
# Entity Name: James Franco
# Entity Type: human
# ---------------
# Freebase ID: /m/08nhfc1
# Entity Name: Crazy Heart
# Entity Type: film
# ---------------
# Freebase ID: /m/015c4g
# Entity Name: Robert Duvall
# Entity Type: human
# ---------------
# Freebase ID: /m/0g56t9t
# Entity Name: Frankenweenie
# Entity Type: 3D film
# ---------------
# Freebase ID: /m/062zm5h
# Entity Name: The Avengers
# Entity Type: film
# ---------------
# Freebase ID: /m/0c9xjl
# Entity Name: Clark Gregg
# Entity Type: human
# ---------------
# Freebase ID: /m/0160w
# Entity Name: The Bahamas
# Entity Type: country
# ---------------
# Freebase ID: /m/0dbpyd
# Entity Name: Alan Burnett
# Entity Type: human
# ---------------
# Freebase ID: /m/053y0s
# Entity Name: Bill Payne
# Entity Type: human
# ---------------
# Freebase ID: /m/0dz3r
# Entity Name: record producer
# Entity Type: musical profession
# ---------------
# Freebase ID: /m/016qtt
# Entity Name: Billy Ray Cyrus
# Entity Type: human
# ---------------
# Freebase ID: /m/0b005
# Entity Name: The Muppet Show
# Entity Type: television series
# ---------------
# Freebase ID: /m/07c52
# Entity Name: television
# Entity Type: infrastructure
# ---------------
# Freebase ID: /m/023wyl
# Entity Name: cornerback
# Entity Type: American football position
# ---------------
# Freebase ID: /m/02wvfxl
# Entity Name: Boston College Eagles football
# Entity Type: American football team
# ---------------
# Freebase ID: /m/09sh8k
# Entity Name: Fantastic Four: Rise of the Silver Surfer
# Entity Type: film
# ---------------
# Freebase ID: /m/09zzb8
# Entity Name: make-up artist
# Entity Type: profession
# ---------------
# Freebase ID: /m/05pd94v
# Entity Name: 52nd Annual Grammy Awards
# Entity Type: award ceremony
# ---------------
# Freebase ID: /m/01vvydl
# Entity Name: Dr. Dre
# Entity Type: human
# ---------------
# Freebase ID: /m/0gtsx8c
# Entity Name: American Reunion
# Entity Type: film
# ---------------
# Freebase ID: /m/0jgd
# Entity Name: Argentina
# Entity Type: country
# ---------------
# Freebase ID: /m/02r0csl
# Entity Name: BAFTA Award for Best Makeup and Hair
# Entity Type: British Academy Film Awards
# ---------------
# Freebase ID: /m/0m313
# Entity Name: Shakespeare in Love
# Entity Type: film
# ---------------
# Freebase ID: /m/02y_lrp
# Entity Name: The Love Guru
# Entity Type: film
# ---------------
# Freebase ID: /m/012d40
# Entity Name: Jackie Chan
# Entity Type: human
# ---------------
# Freebase ID: /m/034qmv
# Entity Name: Around the World in 80 Days
# Entity Type: feature film
# ---------------
# Freebase ID: /m/07rlg
# Entity Name: triathlon
# Entity Type: type of sport
# ---------------
# Freebase ID: /m/0b90_r
# Entity Name: Mexico
# Entity Type: country
# ---------------
# Freebase ID: /m/0g22z
# Entity Name: Wall Street
# Entity Type: film
# ---------------
# Freebase ID: /m/05b4l5x
# Entity Name: Golden Raspberry Award for Worst Supporting Actress
# Entity Type: Golden Raspberry Awards
# ---------------
# Freebase ID: /m/018js4
# Entity Name: Top Gun
# Entity Type: film
# ---------------
# Freebase ID: /m/07fq1y
# Entity Name: Rosemary Harris
# Entity Type: human
# ---------------
# Freebase ID: /m/02qgqt
# Entity Name: Philip Seymour Hoffman
# Entity Type: human
# ---------------
# Freebase ID: /m/081jbk
# Entity Name: Hilary Haag
# Entity Type: human
# ---------------
# Freebase ID: /m/02v5xg
# Entity Name: RahXephon
# Entity Type: anime television series
# ---------------
# Freebase ID: /m/028q6
# Entity Name: Dave Brubeck
# Entity Type: human
# ---------------
# Freebase ID: /m/02581q
# Entity Name: Grammy Award for Best Classical Crossover Album
# Entity Type: class of award
# ---------------
# Freebase ID: /m/0sxg4
# Entity Name: The Dresser
# Entity Type: film
# ---------------
# Freebase ID: /m/04xvlr
# Entity Name: historical drama
# Entity Type: fiction genre
# ---------------
# Freebase ID: /m/02gpkt
# Entity Name: Rush Hour
# Entity Type: film
# ---------------
# Freebase ID: /m/0fvf9q
# Entity Name: Scott Rudin
# Entity Type: human
# ---------------
# Freebase ID: /m/0l6qt
# Entity Name: Alan Bennett
# Entity Type: human
# ---------------
# Freebase ID: /m/07jnt
# Entity Name: The Shawshank Redemption
# Entity Type: film
# ---------------
# Freebase ID: /m/0gq9h
# Entity Name: Academy Award for Best Picture
# Entity Type: Academy Awards
# ---------------
# Freebase ID: /m/0jz9f
# Entity Name: Miramax
# Entity Type: film distributor
# ---------------
# Freebase ID: /m/083shs
# Entity Name: The Cider House Rules
# Entity Type: film
# ---------------
# Freebase ID: /m/0njvn
# Entity Name: Berrien County
# Entity Type: county of Michigan
# ---------------
# Freebase ID: /m/09nqf
# Entity Name: United States dollar
# Entity Type: currency
# ---------------
# Freebase ID: /m/0d1tm
# Entity Name: eventing
# Entity Type: Olympic sport
# ---------------
# Freebase ID: /m/0154j
# Entity Name: Belgium
# Entity Type: country
# ---------------
# Freebase ID: /m/01br2w
# Entity Name: The Passion of the Christ
# Entity Type: film
# ---------------
# Freebase ID: /m/0kq0q
# Entity Name: Calaveras County
# Entity Type: county of California
# ---------------
# Freebase ID: /m/03rl1g
# Entity Name: 32nd United States Congress
# Entity Type: legislative term
# ---------------
# Freebase ID: /m/05kkh
# Entity Name: Ohio
# Entity Type: U.S. state
# ---------------
# Freebase ID: /m/0fbq2n
# Entity Name: Oregon Ducks football
# Entity Type: American football team
# ---------------
# Freebase ID: /m/01r3hr
# Entity Name: running back
# Entity Type: American football position
# ---------------
# Freebase ID: /m/060bp
# Entity Name: prime minister
# Entity Type: position
# ---------------
# Freebase ID: /m/027nb
# Entity Name: Dominica
# Entity Type: country
# ---------------
# Freebase ID: /m/04qvl7
# Entity Name: Roger Deakins
# Entity Type: human
# ---------------
# Freebase ID: /m/02vxq9m
# Entity Name: Skyfall
# Entity Type: film
# ---------------
# Freebase ID: /m/04yywz
# Entity Name: Burt Young
# Entity Type: human
# ---------------
# Freebase ID: /m/0140g4
# Entity Name: Rocky V
# Entity Type: film
# ---------------
# Freebase ID: /m/01k7d9
# Entity Name: Ray Walston
# Entity Type: human
# ---------------
# Freebase ID: /m/0k049
# Entity Name: Beverly Hills
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/02p65p
# Entity Name: Don Cheadle
# Entity Type: human
# ---------------
# Freebase ID: /m/0337vz
# Entity Name: Larenz Tate
# Entity Type: human
# ---------------
# Freebase ID: /m/06688p
# Entity Name: John Barrowman
# Entity Type: human
# ---------------
# Freebase ID: /m/0b2v79
# Entity Name: The Untouchables
# Entity Type: film
# ---------------
# Freebase ID: /m/01c0cc
# Entity Name: Technical University of Berlin
# Entity Type: institute of technology
# ---------------
# Freebase ID: /m/01jc6q
# Entity Name: Cabaret
# Entity Type: film
# ---------------
# Freebase ID: /m/040njc
# Entity Name: BAFTA Award for Best Film
# Entity Type: British Academy Film Awards
# ---------------
# Freebase ID: /m/01wmjkb
# Entity Name: Steven Tyler
# Entity Type: human
# ---------------
# Freebase ID: /m/0l14j_
# Entity Name: flute
# Entity Type: type of musical instrument
# ---------------
# Freebase ID: /m/0520r2x
# Entity Name: Richard Day
# Entity Type: human
# ---------------
# Freebase ID: /m/0cb77r
# Entity Name: Thomas Little
# Entity Type: human
# ---------------
# Freebase ID: /m/06j0md
# Entity Name: James Burrows
# Entity Type: human
# ---------------
# Freebase ID: /m/05mgj0
# Entity Name: UK Film Council
# Entity Type: organization
# ---------------
# Freebase ID: /m/0ds6bmk
# Entity Name: Tyrannosaur
# Entity Type: film
# ---------------
# Freebase ID: /m/05b3ts
# Entity Name: safety
# Entity Type: American football position
# ---------------
# Freebase ID: /m/0g2hw4
# Entity Name: Oregon State Beavers football
# Entity Type: American football team
# ---------------
# Freebase ID: /m/0ktpx
# Entity Name: Spellbound
# Entity Type: film
# ---------------
# Freebase ID: /m/0hqcy
# Entity Name: David O. Selznick
# Entity Type: human
# ---------------
# Freebase ID: /m/01453
# Entity Name: ACF Fiorentina
# Entity Type: association football club
# ---------------
# Freebase ID: /m/0dgrmp
# Entity Name: goalkeeper
# Entity Type: association football position
# ---------------
# Freebase ID: /m/028_yv
# Entity Name: Once Upon a Time in America
# Entity Type: film
# ---------------
# Freebase ID: /m/03rjj
# Entity Name: Italy
# Entity Type: country
# ---------------
# Freebase ID: /m/01914
# Entity Name: Beijing
# Entity Type: city
# ---------------
# Freebase ID: /m/0bpbhm
# Entity Name: Cookie's Fortune
# Entity Type: film
# ---------------
# Freebase ID: /m/0219x_
# Entity Name: independent film
# Entity Type: film genre
# ---------------
# Freebase ID: /m/05_6_y
# Entity Name: David Healy
# Entity Type: human
# ---------------
# Freebase ID: /m/02b15h
# Entity Name: Doncaster Rovers F.C.
# Entity Type: association football club
# ---------------
# Freebase ID: /m/0487c3
# Entity Name: Jason Roberts
# Entity Type: human
# ---------------
# Freebase ID: /m/01j_jh
# Entity Name: Bristol Rovers F.C.
# Entity Type: association football club
# ---------------
# Freebase ID: /m/03c7ln
# Entity Name: Jay Bennett
# Entity Type: human
# ---------------
# Freebase ID: /m/026t6
# Entity Name: drum
# Entity Type: family of musical instruments
# ---------------
# Freebase ID: /m/01qvcr
# Entity Name: Rare Ltd.
# Entity Type: video game developer
# ---------------
# Freebase ID: /m/04sv4
# Entity Name: Microsoft
# Entity Type: public company
# ---------------
# Freebase ID: /m/02pprs
# Entity Name: alto saxophone
# Entity Type: musical instrument
# ---------------
# Freebase ID: /m/07s3vqk
# Entity Name: Ray Charles
# Entity Type: human
# ---------------
# Freebase ID: /m/0d05q4
# Entity Name: Iraq
# Entity Type: country
# ---------------
# Freebase ID: /m/0784z
# Entity Name: Six-Day War
# Entity Type: war
# ---------------
# Freebase ID: /m/0kwgs
# Entity Name: Madison County
# Entity Type: county of Alabama
# ---------------
# Freebase ID: /m/0gyh
# Entity Name: Alabama
# Entity Type: U.S. state
# ---------------
# Freebase ID: /m/01gbbz
# Entity Name: Ellen DeGeneres
# Entity Type: human
# ---------------
# Freebase ID: /m/035ktt
# Entity Name: University of New Orleans
# Entity Type: university
# ---------------
# Freebase ID: /m/05zjtn4
# Entity Name: University of North Texas
# Entity Type: public educational institution of the United States
# ---------------
# Freebase ID: /m/0197tq
# Entity Name: Norah Jones
# Entity Type: human
# ---------------
# Freebase ID: /m/02_fm2
# Entity Name: Treasure Planet
# Entity Type: animated feature film
# ---------------
# Freebase ID: /m/02x73k6
# Entity Name: National Society of Film Critics Award for Best Supporting Actor
# Entity Type: National Society of Film Critics Award
# ---------------
# Freebase ID: /m/02lxrv
# Entity Name: Ed Wood
# Entity Type: film
# ---------------
# Freebase ID: /m/0411q
# Entity Name: John Lee Hooker
# Entity Type: human
# ---------------
# Freebase ID: /m/016z4k
# Entity Name: singer-songwriter
# Entity Type: occupation
# ---------------
# Freebase ID: /m/06151l
# Entity Name: Freddy Rodriguez
# Entity Type: human
# ---------------
# Freebase ID: /m/06gp3f
# Entity Name: Justina Machado
# Entity Type: human
# ---------------
# Freebase ID: /m/01fq7
# Entity Name: Battle Creek
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/06w99h3
# Entity Name: Rango
# Entity Type: animated feature film
# ---------------
# Freebase ID: /m/02kdv5l
# Entity Name: action film
# Entity Type: film genre
# ---------------
# Freebase ID: /m/05cljf
# Entity Name: Keith Urban
# Entity Type: human
# ---------------
# Freebase ID: /m/08r4x3
# Entity Name: Bobby
# Entity Type: film
# ---------------
# Freebase ID: /m/03_6y
# Entity Name: Joshua Jackson
# Entity Type: human
# ---------------
# Freebase ID: /m/0342h
# Entity Name: guitar
# Entity Type: type of musical instrument
# ---------------
# Freebase ID: /m/0l14qv
# Entity Name: synthesizer
# Entity Type: type of musical instrument
# ---------------
# Freebase ID: /m/02bfmn
# Entity Name: Brad Dourif
# Entity Type: human
# ---------------
# Freebase ID: /m/05zppz
# Entity Name: male organism
# Entity Type: biological sex
# ---------------
# Freebase ID: /m/0kc6x
# Entity Name: ESPN
# Entity Type: specialty channel
# ---------------
# Freebase ID: /m/01xdf5
# Entity Name: Stephen Colbert
# Entity Type: human
# ---------------
# Freebase ID: /m/04t2l2
# Entity Name: Steve Carell
# Entity Type: human
# ---------------
# Freebase ID: /m/02rc4d
# Entity Name: Goku
# Entity Type: film character
# ---------------
# Freebase ID: /m/0g0vx
# Entity Name: farmer
# Entity Type: occupation
# ---------------
# Freebase ID: /m/027qgy
# Entity Name: My Big Fat Greek Wedding
# Entity Type: film
# ---------------
# Freebase ID: /m/06cvj
# Entity Name: romantic comedy
# Entity Type: fiction genre
# ---------------
# Freebase ID: /m/01mkq
# Entity Name: computer science
# Entity Type: academic major
# ---------------
# Freebase ID: /m/011xy1
# Entity Name: Trinity College Dublin
# Entity Type: collegiate university
# ---------------
# Freebase ID: /m/0dxtw
# Entity Name: special effects
# Entity Type: cinematic technique
# ---------------
# Freebase ID: /m/0cq86w
# Entity Name: Oliver!
# Entity Type: film
# ---------------
# Freebase ID: /m/02v8kmz
# Entity Name: Bulworth
# Entity Type: film
# ---------------
# Freebase ID: /m/01j5ts
# Entity Name: Anjelica Huston
# Entity Type: human
# ---------------
# Freebase ID: /m/06_kh
# Entity Name: Santa Monica
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/02hrh1q
# Entity Name: actor
# Entity Type: profession
# ---------------
# Freebase ID: /m/01pcz9
# Entity Name: Portia de Rossi
# Entity Type: human
# ---------------
# Freebase ID: /m/0dwl2
# Entity Name: Valve Corporation
# Entity Type: video game developer
# ---------------
# Freebase ID: /m/01mw1
# Entity Name: video game
# Entity Type: software category
# ---------------
# Freebase ID: /m/02wh75
# Entity Name: Grammy Award for Best Rock Song
# Entity Type: Grammy Awards
# ---------------
# Freebase ID: /m/0lbj1
# Entity Name: Sting
# Entity Type: human
# ---------------
# Freebase ID: /m/0c3ybss
# Entity Name: Insidious
# Entity Type: film
# ---------------
# Freebase ID: /m/03cfjg
# Entity Name: Marty Stuart
# Entity Type: human
# ---------------
# Freebase ID: /m/0jzphpx
# Entity Name: 1994 Grammy Awards
# Entity Type: award ceremony
# ---------------
# Freebase ID: /m/06wxw
# Entity Name: St. Louis
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/0jbk9
# Entity Name: United States Department of Housing and Urban Development
# Entity Type: United States federal executive department
# ---------------
# Freebase ID: /m/0np9r
# Entity Name: voice actor
# Entity Type: profession
# ---------------
# Freebase ID: /m/05bp8g
# Entity Name: Kaneto Shiozawa
# Entity Type: human
# ---------------
# Freebase ID: /m/01l1b90
# Entity Name: Tyrese Gibson
# Entity Type: human
# ---------------
# Freebase ID: /m/0p07l
# Entity Name: El Paso County
# Entity Type: county of Colorado
# ---------------
# Freebase ID: /m/01vsl
# Entity Name: Colorado Springs
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/02vp1f_
# Entity Name: Quest for Fire
# Entity Type: film
# ---------------
# Freebase ID: /m/03_3d
# Entity Name: Japan
# Entity Type: country
# ---------------
# Freebase ID: /m/060__y
# Entity Name: film based on literature
# Entity Type: film genre
# ---------------
# Freebase ID: /m/03rtz1
# Entity Name: North
# Entity Type: film
# ---------------
# Freebase ID: /m/09m6kg
# Entity Name: A Beautiful Mind
# Entity Type: film
# ---------------
# Freebase ID: /m/02h40lc
# Entity Name: English
# Entity Type: natural language
# ---------------
# Freebase ID: /m/047q2k1
# Entity Name: 3 Idiots
# Entity Type: film
# ---------------
# Freebase ID: /m/05p553
# Entity Name: comedy
# Entity Type: genre
# ---------------
# Freebase ID: /m/01ypc
# Entity Name: Cincinnati Reds
# Entity Type: baseball team
# ---------------
# Freebase ID: /m/02dwn9
# Entity Name: starting pitcher
# Entity Type: baseball position
# ---------------
# Freebase ID: /m/01k_0fp
# Entity Name: Roger Daltrey
# Entity Type: human
# ---------------
# Freebase ID: /m/0m77m
# Entity Name: Doris Lessing
# Entity Type: human
# ---------------
# Freebase ID: /m/02_h0
# Entity Name: feminism
# Entity Type: ideology
# ---------------
# Freebase ID: /m/06dv3
# Entity Name: Russell Crowe
# Entity Type: human
# ---------------
# Freebase ID: /m/01rtm4
# Entity Name: Sarah Lawrence College
# Entity Type: liberal arts college in the United States
# ---------------
# Freebase ID: /m/02rchht
# Entity Name: Jon Avnet
# Entity Type: human
# ---------------
# Freebase ID: /m/0dq3c
# Entity Name: vice president
# Entity Type: position
# ---------------
# Freebase ID: /m/02zs4
# Entity Name: Ford Motor Company
# Entity Type: holding company
# ---------------
# Freebase ID: /m/0qcr0
# Entity Name: cancer
# Entity Type: class of disease
# ---------------
# Freebase ID: /m/0byfz
# Entity Name: Laurence Olivier
# Entity Type: human
# ---------------
# Freebase ID: /m/06wzvr
# Entity Name: Can't Stop the Music
# Entity Type: film
# ---------------
# Freebase ID: /m/01qn7n
# Entity Name: The O.C.
# Entity Type: television series
# ---------------
# Freebase ID: /m/016tw3
# Entity Name: Universal Pictures
# Entity Type: organization
# ---------------
# Freebase ID: /m/03tps5
# Entity Name: Meet the Fockers
# Entity Type: film
# ---------------
# Freebase ID: /m/0cnl80
# Entity Name: Phyllis Smith
# Entity Type: human
# ---------------
# Freebase ID: /m/083chw
# Entity Name: Rainn Wilson
# Entity Type: human
# ---------------
# Freebase ID: /m/0gq_v
# Entity Name: Academy Award for Best Production Design
# Entity Type: Academy Awards
# ---------------
# Freebase ID: /m/0k2cb
# Entity Name: Dangerous Liaisons
# Entity Type: film
# ---------------
# Freebase ID: /m/0qf43
# Entity Name: Danny Boyle
# Entity Type: human
# ---------------
# Freebase ID: /m/0f_nbyh
# Entity Name: Producers Guild of America Award for Best Theatrical Motion Picture
# Entity Type: Producers Guild of America Awards
# ---------------
# Freebase ID: /m/0c0yh4
# Entity Name: Sunshine
# Entity Type: film
# ---------------
# Freebase ID: /m/0d060g
# Entity Name: Canada
# Entity Type: country
# ---------------
# Freebase ID: /m/05qt0
# Entity Name: politics
# Entity Type: academic discipline
# ---------------
# Freebase ID: /m/0nk72
# Entity Name: Hannah Arendt
# Entity Type: human
# ---------------
# Freebase ID: /m/01s3kv
# Entity Name: Fran Drescher
# Entity Type: human
# ---------------
# Freebase ID: /m/03g90h
# Entity Name: Babylon 5: The Gathering
# Entity Type: television film
# ---------------
# Freebase ID: /m/06cqb
# Entity Name: reggae
# Entity Type: music genre
# ---------------
# Freebase ID: /m/0827d
# Entity Name: world music
# Entity Type: music genre
# ---------------
# Freebase ID: /m/02tkzn
# Entity Name: Ed Asner
# Entity Type: human
# ---------------
# Freebase ID: /m/014zcr
# Entity Name: George Clooney
# Entity Type: human
# ---------------
# Freebase ID: /m/05m63c
# Entity Name: Krista Allen
# Entity Type: human
# ---------------
# Freebase ID: /m/0yyg4
# Entity Name: Mississippi Burning
# Entity Type: film
# ---------------
# Freebase ID: /m/027c924
# Entity Name: National Board of Review Award for Best Director
# Entity Type: National Board of Review Awards
# ---------------
# Freebase ID: /m/03f0324
# Entity Name: Franz Kafka
# Entity Type: human
# ---------------
# Freebase ID: /m/040rjq
# Entity Name: Martin McDonagh
# Entity Type: human
# ---------------
# Freebase ID: /m/01tv3x2
# Entity Name: Tim Armstrong
# Entity Type: human
# ---------------
# Freebase ID: /m/06rqw
# Entity Name: ska
# Entity Type: music genre
# ---------------
# Freebase ID: /m/0h3y
# Entity Name: Algeria
# Entity Type: country
# ---------------
# Freebase ID: /m/0rtv
# Entity Name: Algiers
# Entity Type: city
# ---------------
# Freebase ID: /m/090s_0
# Entity Name: Gulliver's Travels
# Entity Type: miniseries
# ---------------
# Freebase ID: /m/0h0jz
# Entity Name: Peter O'Toole
# Entity Type: human
# ---------------
# Freebase ID: /m/05znxx
# Entity Name: The Fugitive
# Entity Type: film
# ---------------
# Freebase ID: /m/02hsq3m
# Entity Name: BAFTA Award for Best Special Visual Effects
# Entity Type: British Academy Film Awards
# ---------------
# Freebase ID: /m/01kyvx
# Entity Name: seiyū
# Entity Type: profession
# ---------------
# Freebase ID: /m/0ckr7s
# Entity Name: Sailor Moon R: The Movie
# Entity Type: anime film
# ---------------
# Freebase ID: /m/02ky346
# Entity Name: engineering
# Entity Type: field of work
# ---------------
# Freebase ID: /m/0p5wz
# Entity Name: University of Southampton
# Entity Type: higher education institution
# ---------------
# Freebase ID: /m/05ztjjw
# Entity Name: MTV Movie Award for Best Movie
# Entity Type: MTV Movie & TV Awards
# ---------------
# Freebase ID: /m/01gc7
# Entity Name: Braveheart
# Entity Type: film
# ---------------
# Freebase ID: /m/04j53
# Entity Name: Liechtenstein
# Entity Type: country
# ---------------
# Freebase ID: /m/04h68j
# Entity Name: James Wong
# Entity Type: human
# ---------------
# Freebase ID: /m/01g3gq
# Entity Name: Final Destination
# Entity Type: film
# ---------------
# Freebase ID: /m/01vw87c
# Entity Name: Jon Bon Jovi
# Entity Type: human
# ---------------
# Freebase ID: /m/01gbcf
# Entity Name: math rock
# Entity Type: music genre
# ---------------
# Freebase ID: /m/016clz
# Entity Name: alternative rock
# Entity Type: music genre
# ---------------
# Freebase ID: /m/011yrp
# Entity Name: Life is Beautiful
# Entity Type: film
# ---------------
# Freebase ID: /m/0d0vqn
# Entity Name: Sweden
# Entity Type: country
# ---------------
# Freebase ID: /m/049tjg
# Entity Name: Van Johnson
# Entity Type: human
# ---------------
# Freebase ID: /m/05jf85
# Entity Name: The Purple Rose of Cairo
# Entity Type: film
# ---------------
# Freebase ID: /m/046f25
# Entity Name: Grenada national football team
# Entity Type: national association football team
# ---------------
# Freebase ID: /m/0d1swh
# Entity Name: Craig Rocastle
# Entity Type: human
# ---------------
# Freebase ID: /m/0b_fw
# Entity Name: Anthony Quinn
# Entity Type: human
# ---------------
# Freebase ID: /m/04t36
# Entity Name: musical film
# Entity Type: film genre
# ---------------
# Freebase ID: /m/011yxg
# Entity Name: Moulin Rouge!
# Entity Type: film
# ---------------
# Freebase ID: /m/05v38p
# Entity Name: Chocolat
# Entity Type: film
# ---------------
# Freebase ID: /m/03hkv_r
# Entity Name: Writers Guild of America Award for Best Adapted Screenplay
# Entity Type: Writers Guild of America Award
# ---------------
# Freebase ID: /m/025twgf
# Entity Name: Dr. No
# Entity Type: film
# ---------------
# Freebase ID: /m/0clpml
# Entity Name: James Bond
# Entity Type: book series
# ---------------
# Freebase ID: /m/0t015
# Entity Name: Iowa City
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/0j1z8
# Entity Name: United Arab Emirates
# Entity Type: country
# ---------------
# Freebase ID: /m/07t65
# Entity Name: United Nations
# Entity Type: organization
# ---------------
# Freebase ID: /m/0162b
# Entity Name: Bangladesh
# Entity Type: country
# ---------------
# Freebase ID: /m/0fnb4
# Entity Name: Dhaka
# Entity Type: city
# ---------------
# Freebase ID: /m/0hd7j
# Entity Name: University of Mississippi
# Entity Type: public university
# ---------------
# Freebase ID: /m/07xl34
# Entity Name: chancellor
# Entity Type: job title
# ---------------
# Freebase ID: /m/02sgy
# Entity Name: electric guitar
# Entity Type: type of musical instrument
# ---------------
# Freebase ID: /m/0l14md
# Entity Name: percussion instrument
# Entity Type: family of musical instruments
# ---------------
# Freebase ID: /m/0c9d9
# Entity Name: Jean-Michel Jarre
# Entity Type: human
# ---------------
# Freebase ID: /m/02g8h
# Entity Name: Denis Leary
# Entity Type: human
# ---------------
# Freebase ID: /m/01d_h8
# Entity Name: film producer
# Entity Type: filmmaking occupation
# ---------------
# Freebase ID: /m/0c_j9x
# Entity Name: Murder on the Orient Express
# Entity Type: film
# ---------------
# Freebase ID: /m/0n5j_
# Entity Name: Bergen County
# Entity Type: county of New Jersey
# ---------------
# Freebase ID: /m/0fm9_
# Entity Name: Rockland County
# Entity Type: county of New York
# ---------------
# Freebase ID: /m/04cy8rb
# Entity Name: Conrad Buff IV
# Entity Type: human
# ---------------
# Freebase ID: /m/07gp9
# Entity Name: Terminator 2: Judgment Day
# Entity Type: film
# ---------------
# Freebase ID: /m/081pw
# Entity Name: World War II
# Entity Type: world war
# ---------------
# Freebase ID: /m/0gzy02
# Entity Name: The Guns of Navarone
# Entity Type: film
# ---------------
# Freebase ID: /m/05g8ky
# Entity Name: Josh Schwartz
# Entity Type: human
# ---------------
# Freebase ID: /m/026wp
# Entity Name: democracy
# Entity Type: form of state
# ---------------
# Freebase ID: /m/049nq
# Entity Name: Kingdom of the Netherlands
# Entity Type: country
# ---------------
# Freebase ID: /m/03t5kl
# Entity Name: Grammy Award for Best Melodic Rap Performance
# Entity Type: Grammy Awards
# ---------------
# Freebase ID: /m/01f2q5
# Entity Name: The Roots
# Entity Type: musical group
# ---------------
# Freebase ID: /m/01jssp
# Entity Name: University of Pittsburgh
# Entity Type: public–private partnership
# ---------------
# Freebase ID: /m/01l849
# Entity Name: gold
# Entity Type: color
# ---------------
# Freebase ID: /m/0f4y_
# Entity Name: Delaware County
# Entity Type: county of New York
# ---------------
# Freebase ID: /m/08959
# Entity Name: Zachary Taylor
# Entity Type: human
# ---------------
# Freebase ID: /m/0789n
# Entity Name: secretary of state
# Entity Type: position
# ---------------
# Freebase ID: /m/01fkr_
# Entity Name: VH1 USA
# Entity Type: specialty channel
# ---------------
# Freebase ID: /m/0mdxd
# Entity Name: music video
# Entity Type: type of cinematic work
# ---------------
# Freebase ID: /m/03x3qv
# Entity Name: Joshua Malina
# Entity Type: human
# ---------------
# Freebase ID: /m/0g60z
# Entity Name: The West Wing
# Entity Type: television series
# ---------------
# Freebase ID: /m/0d_84
# Entity Name: Val Kilmer
# Entity Type: human
# ---------------
# Freebase ID: /m/01hr1
# Entity Name: Batman Forever
# Entity Type: film
# ---------------
# Freebase ID: /m/042l3v
# Entity Name: Herbert Ross
# Entity Type: human
# ---------------
# Freebase ID: /m/026mg3
# Entity Name: Grammy Award for Best Country Instrumental Performance
# Entity Type: class of award
# ---------------
# Freebase ID: /m/01s695
# Entity Name: 42nd Annual Grammy Awards
# Entity Type: award ceremony
# ---------------
# Freebase ID: /m/0gtt5fb
# Entity Name: The Great Gatsby
# Entity Type: film
# ---------------
# Freebase ID: /m/0tj9
# Entity Name: Amitabh Bachchan
# Entity Type: human
# ---------------
# Freebase ID: /m/0hx4y
# Entity Name: Jurassic Park
# Entity Type: film
# ---------------
# Freebase ID: /m/01y_px
# Entity Name: Jeff Goldblum
# Entity Type: human
# ---------------
# Freebase ID: /m/0k611
# Entity Name: Academy Award for Best Film Editing
# Entity Type: Academy Awards
# ---------------
# Freebase ID: /m/0hsmh
# Entity Name: Robert Wise
# Entity Type: human
# ---------------
# Freebase ID: /m/0gx1bnj
# Entity Name: Seeking a Friend for the End of the World
# Entity Type: film
# ---------------
# Freebase ID: /m/04gzd
# Entity Name: Lithuania
# Entity Type: country
# ---------------
# Freebase ID: /m/04njml
# Entity Name: Tony Award for Best Original Score
# Entity Type: theatre award
# ---------------
# Freebase ID: /m/07hgkd
# Entity Name: David Shire
# Entity Type: human
# ---------------
# Freebase ID: /m/04wlz2
# Entity Name: Hampton University
# Entity Type: university
# ---------------
# Freebase ID: /m/01531
# Entity Name: The Bronx
# Entity Type: borough of New York City
# ---------------
# Freebase ID: /m/0b1f49
# Entity Name: Brad Grey
# Entity Type: human
# ---------------
# Freebase ID: /m/01gxqf
# Entity Name: Macclesfield Town F.C.
# Entity Type: defunct association football club
# ---------------
# Freebase ID: /m/01_qc_
# Entity Name: pancreatic cancer
# Entity Type: class of disease
# ---------------
# Freebase ID: /m/0c55fj
# Entity Name: BBC HD
# Entity Type: television channel
# ---------------
# Freebase ID: /m/09xbpt
# Entity Name: Ocean's Thirteen
# Entity Type: film
# ---------------
# Freebase ID: /m/0yxl
# Entity Name: Alan Moore
# Entity Type: human
# ---------------
# Freebase ID: /m/02w7gg
# Entity Name: English people
# Entity Type: nation
# ---------------
# Freebase ID: /m/05f4m9q
# Entity Name: Golden Raspberry Award for Worst Director
# Entity Type: Golden Raspberry Awards
# ---------------
# Freebase ID: /m/08lr6s
# Entity Name: The Scarlet Letter
# Entity Type: film
# ---------------
# Freebase ID: /m/09y20
# Entity Name: Alan Rickman
# Entity Type: human
# ---------------
# Freebase ID: /m/01nrnm
# Entity Name: Royal College of Art
# Entity Type: higher education institution
# ---------------
# Freebase ID: /m/0hl3d
# Entity Name: Pierre Boulez
# Entity Type: human
# ---------------
# Freebase ID: /m/0cbd2
# Entity Name: writer
# Entity Type: profession
# ---------------
# Freebase ID: /m/0495ys
# Entity Name: 93rd United States Congress
# Entity Type: legislative term
# ---------------
# Freebase ID: /m/05l2z4
# Entity Name: 90th United States Congress
# Entity Type: legislative term
# ---------------
# Freebase ID: /m/018wrk
# Entity Name: 1904 Summer Olympics
# Entity Type: Summer Olympic Games
# ---------------
# Freebase ID: /m/02bkg
# Entity Name: diving
# Entity Type: type of sport
# ---------------
# Freebase ID: /m/0h5f5n
# Entity Name: Peter Morgan
# Entity Type: human
# ---------------
# Freebase ID: /m/04jpl
# Entity Name: London
# Entity Type: city
# ---------------
# Freebase ID: /m/047gn4y
# Entity Name: Prince of Persia: The Sands of Time
# Entity Type: feature film
# ---------------
# Freebase ID: /m/05ty4m
# Entity Name: Judd Apatow
# Entity Type: human
# ---------------
# Freebase ID: /m/0bvn25
# Entity Name: Knocked Up
# Entity Type: film
# ---------------
# Freebase ID: /m/026p4q7
# Entity Name: The Curious Case of Benjamin Button
# Entity Type: film
# ---------------
# Freebase ID: /m/044lyq
# Entity Name: Jared Harris
# Entity Type: human
# ---------------
# Freebase ID: /m/01vs5c
# Entity Name: University of Oklahoma
# Entity Type: public educational institution of the United States
# ---------------
# Freebase ID: /m/09jvl
# Entity Name: NOFX
# Entity Type: musical group
# ---------------
# Freebase ID: /m/01g888
# Entity Name: ska punk
# Entity Type: music genre
# ---------------
# Freebase ID: /m/01vrx3g
# Entity Name: Levon Helm
# Entity Type: human
# ---------------
# Freebase ID: /m/01lmj3q
# Entity Name: Ricky Skaggs
# Entity Type: human
# ---------------
# Freebase ID: /m/0m27n
# Entity Name: Maricopa County
# Entity Type: county of Arizona
# ---------------
# Freebase ID: /m/0qpjt
# Entity Name: Chandler
# Entity Type: city in the United States
# ---------------
# Freebase ID: /m/01c8w0
# Entity Name: conducting
# Entity Type: activity
# ---------------
# Freebase ID: /m/023361
# Entity Name: Jerry Goldsmith
# Entity Type: human
# ---------------
# Freebase ID: /m/01qbg5
# Entity Name: Gia
# Entity Type: film
# ---------------
# Freebase ID: /m/017fp
# Entity Name: biography
# Entity Type: literary genre
# ---------------
# Freebase ID: /m/01gsvb
# Entity Name: 18th United States Congress
# Entity Type: legislative term
# ---------------
# Freebase ID: /m/0b3wk
# Entity Name: United States House of Representatives
# Entity Type: jurisdiction
# ---------------
# Freebase ID: /m/01wbg84
# Entity Name: Steve Buscemi
# Entity Type: human
# ---------------
# Freebase ID: /m/01r42_g
# Entity Name: Jamie-Lynn Sigler
# Entity Type: human
# ---------------
# Freebase ID: /m/0gr51
# Entity Name: Academy Award for Best Writing, Original Screenplay
# Entity Type: Academy Awards
# ---------------
# Freebase ID: /m/04gcd1
# Entity Name: Brad Bird
# Entity Type: human
# ---------------
# Freebase ID: /m/0ddfwj1
# Entity Name: Submarine
# Entity Type: film
# ---------------
# Freebase ID: /m/0sv6n
# Entity Name: Burlington
# Entity Type: county seat
# ---------------
# Freebase ID: /m/02wkmx
# Entity Name: Palme d'Or
# Entity Type: Cannes Film Festival Awards
# ---------------
# Freebase ID: /m/0f5hyg
# Entity Name: Granada CF
# Entity Type: association football club
# ---------------
# Freebase ID: /m/0126y2
# Entity Name: Ja Rule
# Entity Type: human
# ---------------
# Freebase ID: /m/01flzq
# Entity Name: hardcore hip hop
# Entity Type: music genre
# ---------------
# Freebase ID: /m/05cj4r
# Entity Name: Eileen Atkins
# Entity Type: human
# ---------------
# Freebase ID: /m/0bfvw2
# Entity Name: Primetime Emmy Award for Outstanding Supporting Actress in a Miniseries or a Movie
# Entity Type: Primetime Emmy Award
# ---------------
# Freebase ID: /m/023tp8
# Entity Name: Patricia Arquette
# Entity Type: human
# ---------------
# Freebase ID: /m/0dq626
# Entity Name: Holes
# Entity Type: feature film
# ---------------
# Freebase ID: /m/07sbbz2
# Entity Name: rock and roll
# Entity Type: music genre
# ---------------
# Freebase ID: /m/089tm
# Entity Name: ZZ Top
# Entity Type: musical group
# ---------------
# Freebase ID: /m/0m2wm
# Entity Name: Claudia Schiffer
# Entity Type: human
# ---------------
# Freebase ID: /m/02zq43
# Entity Name: Thomas Brodie-Sangster
# Entity Type: human
# ---------------
# Freebase ID: /m/086k8
# Entity Name: Warner Bros.
# Entity Type: film production company
# ---------------
# Freebase ID: /m/0czyxs
# Entity Name: Watchmen
# Entity Type: film
# ---------------
# Freebase ID: /m/014635
# Entity Name: Mark Twain
# Entity Type: human
# ---------------
# Freebase ID: /m/02kz_
# Entity Name: Ernest Hemingway
# Entity Type: human
# ---------------
# Freebase ID: /m/0ds3t5x
# Entity Name: The Help
# Entity Type: film
# ---------------
# Freebase ID: /m/02896
# Entity Name: Dallas Cowboys
# Entity Type: American football team
# ---------------
# Freebase ID: /m/05krk
# Entity Name: Ohio State University
# Entity Type: land-grant university
# ---------------
# Freebase ID: /m/0chghy
# Entity Name: Australia
# Entity Type: country
# ---------------
# Freebase ID: /m/0l6vl
# Entity Name: 1980 Summer Olympics
# Entity Type: Summer Olympic Games
# ---------------
# Freebase ID: /m/02tcgh
# Entity Name: Kal Ho Naa Ho
# Entity Type: film
# ---------------
# Freebase ID: /m/0kvgnq
# Entity Name: The Unbearable Lightness of Being
# Entity Type: film
# ---------------
# Freebase ID: /m/02x4wr9
# Entity Name: Independent Spirit Award for Best Director
# Entity Type: Independent Spirit Awards
# ---------------
# Freebase ID: /m/017z49
# Entity Name: Memento
# Entity Type: film
# ---------------
# Freebase ID: /m/08p1gp
# Entity Name: Luci Christian
# Entity Type: human
# ---------------
# Freebase ID: /m/0dnvn3
# Entity Name: The Ladykillers
# Entity Type: film
# ---------------
# Freebase ID: /m/07zrf
# Entity Name: Vietnamese
# Entity Type: language
# ---------------
# Freebase ID: /m/016fyc
# Entity Name: The Usual Suspects
# Entity Type: film
# ---------------
# Freebase ID: /m/01qscs
# Entity Name: Benicio del Toro
# Entity Type: human
# ---------------
# Freebase ID: /m/01p7yb
# Entity Name: Frances McDormand
# Entity Type: human
# ---------------
# Freebase ID: /m/0p_pd
# Entity Name: Bill Murray
# Entity Type: human
# ---------------
# Freebase ID: /m/0bl2g
# Entity Name: Dustin Hoffman
# Entity Type: human
# ---------------
# Freebase ID: /m/0prfz
# Entity Name: Liev Schreiber
# Entity Type: human
# ---------------
# Freebase ID: /m/02pw_n
# Entity Name: Garden State
# Entity Type: film
# ---------------
# Freebase ID: /m/09l3p
# Entity Name: Natalie Portman
# Entity Type: human
# ---------------
# Freebase ID: /m/0k9ctht
# Entity Name: RKO Pictures
# Entity Type: film distributor
# ---------------
# Freebase ID: /m/0fr63l
# Entity Name: Mighty Joe Young
# Entity Type: feature film
# ---------------
# Freebase ID: /m/01q_ph
# Entity Name: Owen Wilson
# Entity Type: human
# ---------------
# Freebase ID: /m/05zr6wv
# Entity Name: MTV Movie Award for Best On-Screen Duo
# Entity Type: MTV Movie & TV Awards
# ---------------
# Freebase ID: /m/0cjk9
# Entity Name: Ukrainian
# Entity Type: language
# ---------------
# Freebase ID: /m/047lj
# Entity Name: Kazakhstan
# Entity Type: country
# ---------------
# Freebase ID: /m/0s3y5
# Entity Name: Urbana
# Entity Type: county seat
# ---------------
# Freebase ID: /m/09fb5
# Entity Name: Jack Nicholson
# Entity Type: human
# ---------------
# Freebase ID: /m/07xtqq
# Entity Name: One Flew Over the Cuckoo's Nest
# Entity Type: film
# ---------------
# Freebase ID: /m/05hcy
# Entity Name: Nassau
# Entity Type: city
# ---------------
# Freebase ID: /m/0jg1q
# Entity Name: House of Orange-Nassau
# Entity Type: dynasty
# ---------------
# Freebase ID: /m/0c5lg
# Entity Name: judge
# Entity Type: profession
# ---------------
# Freebase ID: /m/0rlz
# Entity Name: Andrew Jackson
# Entity Type: human
# ---------------
# Freebase ID: /m/02ktt7
# Entity Name: Kraft Foods Group
# Entity Type: public company
# ---------------
# Freebase ID: /m/026v437
# Entity Name: Paz de la Huerta
# Entity Type: human
# ---------------
# Freebase ID: /m/080dwhx
# Entity Name: Boardwalk Empire
# Entity Type: television series
# ---------------
# Freebase ID: /m/0150jk
# Entity Name: Nickelback
# Entity Type: rock band
# ---------------
# Freebase ID: /m/05bt6j
# Entity Name: pop rock
# Entity Type: music genre
# ---------------
# Freebase ID: /m/01k1k4
# Entity Name: Austin Powers: The Spy Who Shagged Me
# Entity Type: film
# ---------------
# Freebase ID: /m/09gq0x5
# Entity Name: The King's Speech
# Entity Type: film
# ---------------
# Freebase ID: /m/0gtv7pk
# Entity Name: Resident Evil: Retribution
# Entity Type: film
# ---------------
# Freebase ID: /m/01ls2
# Entity Name: Colombia
# Entity Type: country
# ---------------
# Freebase ID: /m/02rbdlq
# Entity Name: Scottish Canadians
# Entity Type: ethnic group
# ---------------
# Freebase ID: /m/0l8v5
# Entity Name: Neve Campbell
# Entity Type: human
# ---------------
# Freebase ID: /m/095zlp
# Entity Name: The Hours
# Entity Type: film
# ---------------
# Freebase ID: /m/06q2q
# Entity Name: scientist
# Entity Type: profession
# ---------------
# Freebase ID: /m/0hnws
# Entity Name: Iron Man
# Entity Type: comics character
# ---------------
# Freebase ID: /m/09wj5
# Entity Name: Orlando Bloom
# Entity Type: human
# ---------------
# Freebase ID: /m/0m4yg
# Entity Name: Guildhall School of Music and Drama
# Entity Type: university
# ---------------
# Freebase ID: /m/09c7b
# Entity Name: Metropolitan Museum of Art
# Entity Type: art museum
# ---------------
# Freebase ID: /m/0hhbr
# Entity Name: art museum
# Entity Type: type of museum
# ---------------
# Freebase ID: /m/03ckxdg
# Entity Name: Elizabeth Page
# Entity Type: human
# ---------------
# Freebase ID: /m/02_1q9
# Entity Name: Another World
# Entity Type: television series
# ---------------
# Freebase ID: /m/09n48
# Entity Name: 2002 Winter Olympics
# Entity Type: Winter Olympic Games
# ---------------
# Freebase ID: /m/020qr4
# Entity Name: Sonic X
# Entity Type: anime television series
# ---------------
# Freebase ID: /m/03_r3
# Entity Name: Jamaica
# Entity Type: country
# ---------------
# Freebase ID: /m/02lq67
# Entity Name: bronze medal
# Entity Type: medallion
# ---------------
# Freebase ID: /m/0fvwg
# Entity Name: Annapolis
# Entity Type: county seat
# ---------------
# Freebase ID: /m/0dtw1x
# Entity Name: The Aristocrats
# Entity Type: film
# ---------------
# Freebase ID: /m/01yznp
# Entity Name: Penn Jillette
# Entity Type: human
# ---------------
# Freebase ID: /m/01tvz5j
# Entity Name: Maria Bello
# Entity Type: human
# ---------------
# Freebase ID: /m/03rs8y
# Entity Name: Eriq La Salle
# Entity Type: human
# ---------------
# Freebase ID: /m/0h1cdwq
# Entity Name: Alvin and the Chipmunks: Chipwrecked
# Entity Type: feature film
# ---------------
# Freebase ID: /m/03rt9
# Entity Name: Republic of Ireland
# Entity Type: country
# ---------------
# Freebase ID: /m/0m2kd
# Entity Name: Stand by Me
# Entity Type: film
# ---------------
# Freebase ID: /m/0jdk_
# Entity Name: 2000 Summer Olympics
# Entity Type: Summer Olympic Games
# ---------------
# Freebase ID: /m/064vjs
# Entity Name: canoe sprint
# Entity Type: sports discipline
# ---------------
# Freebase ID: /m/025cbm
# Entity Name: clavinet
# Entity Type: musical instrument model
# ---------------
# Freebase ID: /m/03qbh5
# Entity Name: Grammy Award for Best Pop Collaboration with Vocals
# Entity Type: Grammy Awards
# ---------------
# Freebase ID: /m/09hnb
# Entity Name: Herbie Hancock
# Entity Type: human
# ---------------
# Freebase ID: /m/052q4j
# Entity Name: Catholic school
# Entity Type: type of educational institution
# ---------------
# Freebase ID: /m/01fxg8
# Entity Name: Pontifical Gregorian University
# Entity Type: pontifical university
# ---------------
# Freebase ID: /m/0146pg
# Entity Name: John Williams
# Entity Type: human
# ---------------
# Freebase ID: /m/0bzjvm
# Entity Name: 48th Academy Awards
# Entity Type: Academy Awards ceremony
# ---------------
# Freebase ID: /m/0cj_v7
# Entity Name: Derby County F.C.
# Entity Type: association football club
# ---------------
# Freebase ID: /m/0jt90f5
# Entity Name: Stephen King
# Entity Type: human
# ---------------
# Freebase ID: /m/067xw
# Entity Name: Peter David
# Entity Type: human
# ---------------
# Freebase ID: /m/025h4z
# Entity Name: Judd Hirsch
# Entity Type: human
# ---------------
# Freebase ID: /m/0bp_b2
# Entity Name: Primetime Emmy Award for Outstanding Guest Actor in a Drama Series
# Entity Type: Primetime Emmy Award
# ---------------
# Freebase ID: /m/02fqrf
# Entity Name: Batman Begins
# Entity Type: film
# ---------------
# Freebase ID: /m/057xs89
# Entity Name: MTV Movie Award for Best Villain
# Entity Type: MTV Movie & TV Awards
# ---------------
# Freebase ID: /m/05y7hc
# Entity Name: Craig Armstrong
# Entity Type: human
# ---------------
# Freebase ID: /m/01g0p5
# ...
# Entity Type: geographic region
# ---------------
# Freebase ID: /m/013_5c
# Entity Name: New Zealand Labour Party
# Entity Type: political party
# ---------------
# Freebase ID: /m/047f9jp
# Entity Name: Jagdish Raj
# Entity Type: human
# ---------------
# Freebase ID: /m/0g6pl
# Entity Name: Art Nouveau
# Entity Type: architectural style
# ---------------
# Freebase ID: /m/07yqn
# Entity Name: platform game
# Entity Type: video game genre
# ---------------
# Freebase ID: /m/02r20ff
# Entity Name: Out of Iraq Caucus
# Entity Type: congressional caucus
# ---------------
# Freebase ID: /m/0fgsq2
# Entity Name: art dealer
# Entity Type: profession
# ---------------
# Freebase ID: /m/018lc_
# Entity Name: Niagara Falls
# Entity Type: city
# ---------------
# Freebase ID: /m/066d03
# Entity Name: deathcore
# Entity Type: music genre
# ---------------
# Freebase ID: /m/05frqx
# Entity Name: Toronto District School Board
# Entity Type: academic institution
# ---------------
# Freebase ID: /m/01rww3
# Entity Name: K Records
# Entity Type: record label
# ---------------
# Freebase ID: /m/0gyvgw
# Entity Name: Wigan
# Entity Type: town
# ---------------
# Freebase ID: /m/022tzk
# Entity Name: Palomar Mountain Observatory
# Entity Type: astronomical observatory
# ---------------
# Freebase ID: /m/0140xf
# Entity Name: Christmas music
# Entity Type: music genre
# ---------------
# Freebase ID: /m/01sfl
# Entity Name: clown
# Entity Type: circus profession
# ---------------
# Freebase ID: /m/02049g
# Entity Name: Carmarthen
# Entity Type: community
# ---------------
# Freebase ID: /m/01nbk4
# Entity Name: Communist Party of Germany
# Entity Type: communist party
# ---------------
# Freebase ID: /m/06cvx
# Entity Name: Renaissance
# Entity Type: art movement
# ---------------
# Freebase ID: /m/0x2gl
# Entity Name: manslaughter
# Entity Type: manner of death
# ---------------
# Freebase ID: /m/01xq0k1
# Entity Name: cattle
# Entity Type: organisms known by a particular common name
# ---------------
# Freebase ID: /m/02m30v
# Entity Name: Joan Bennett
# Entity Type: human
# ---------------
# Freebase ID: /m/022b_
# Entity Name: Casablanca
# Entity Type: city
# ---------------
# Freebase ID: /m/06zfw
# Entity Name: skateboarding
# Entity Type: type of sport
# ---------------
# Freebase ID: /m/01tlyq
# Entity Name: Ontario Liberal Party
# Entity Type: political party
# ---------------
# Freebase ID: /m/01ld4n
# Entity Name: Congregational churches
# Entity Type: Christian denominational family
# ---------------
# Freebase ID: /m/0hfp
# Entity Name: Afroasiatic
# Entity Type: language family
# ---------------
# Freebase ID: /m/0mz2
# Entity Name: alternate history
# Entity Type: speculative/fantastic fiction genre
# ---------------
# Freebase ID: /m/0kwr
# Entity Name: Anglican Communion
# Entity Type: religious denomination
# ---------------
# Freebase ID: /m/01fhsb
# Entity Name: pastor
# Entity Type: profession
# ---------------
# Freebase ID: /m/04gp3_2
# Entity Name: This TV
# Entity Type: television station
# ---------------
# Freebase ID: /m/019rvp
# Entity Name: Maidstone
# Entity Type: county town
# ---------------
# Freebase ID: /m/03y05ty
# Entity Name: bubonic plague
# Entity Type: class of disease
# ---------------
# Freebase ID: /m/01rng
# Entity Name: County Mayo
# Entity Type: county of Ireland
# ---------------
# Freebase ID: /m/02_tw
# Entity Name: Fine Gael
# Entity Type: political party
# ---------------
# Freebase ID: /m/0kff3
# Entity Name: cougar
# Entity Type: taxon
# ---------------
# Freebase ID: /m/0145m
# Entity Name: Afrobeat
# Entity Type: music genre
# ---------------
# Freebase ID: /m/02p4l6s
# Entity Name: African popular music
# Entity Type: music genre
# ---------------
# Freebase ID: /m/021lkq
# Entity Name: Barnet
# Entity Type: area of London
# ---------------
# Freebase ID: /m/07619_
# Entity Name: strongman
# Entity Type: profession
# ---------------
# Freebase ID: /m/0q245
# Entity Name: Pre-Raphaelite Brotherhood
# Entity Type: art movement
# ---------------
# Freebase ID: /m/02l3gf
# Entity Name: Victorian architecture
# Entity Type: architectural style
# ---------------
# Freebase ID: /m/0c_xl
# Entity Name: statistician
# Entity Type: profession
# ---------------
# Freebase ID: /m/03_2f
# Entity Name: igneous rock
# Entity Type: rock type
# ---------------
# Freebase ID: /m/0fq5j
# Entity Name: Kuwait City
# Entity Type: city
# ---------------
# Freebase ID: /m/012k_9
# Entity Name: Apache License
# Entity Type: software license
# ---------------
# Freebase ID: /m/03gkb0
# Entity Name: socialite
# Entity Type: social class
# ---------------
# Freebase ID: /m/09wc5
# Entity Name: Shiraz
# Entity Type: city of Iran
# ---------------
# Freebase ID: /m/0kcc7
# Entity Name: cinema complex
# Entity Type: class
# ---------------
# Freebase ID: /m/0276bn
# Entity Name: Peoples Democratic Party
# Entity Type: political party
# ---------------
# Freebase ID: /m/03ng8q
# Entity Name: Vagrant Records
# Entity Type: record label
# ---------------
# Freebase ID: /m/01hg2h
# Entity Name: Soviet Air Forces
# Entity Type: air force
# ---------------
# Freebase ID: /m/012xsy
# Entity Name: music of Japan
# Entity Type: music genre
# ---------------
# Freebase ID: /m/01_bhs
# Entity Name: fast food
# Entity Type: industry
# ---------------
# Freebase ID: /m/01zxzp
# Entity Name: psychological horror
# Entity Type: horror genre
# ---------------
# Freebase ID: /m/07yr3
# Entity Name: fighting game
# Entity Type: video game genre
# ---------------
# Freebase ID: /m/025sh_8
# Entity Name: Washington metropolitan area
# Entity Type: capital region
# ---------------
# Freebase ID: /m/0fqpg6b
# Entity Name: AACTA Award for Best Guest or Supporting Actor in a Television Drama
# Entity Type: AACTA Awards
# ---------------
# Freebase ID: /m/07vzd
# Entity Name: politics of the United States
# Entity Type: political system
# ---------------
# Freebase ID: /m/0g_tv
# Entity Name: Montmartre Cemetery
# Entity Type: cemetery
# ---------------
# Freebase ID: /m/013rxq
# Entity Name: tejano music
# Entity Type: music genre
# ---------------
# Freebase ID: /m/053f5
# Entity Name: mountaineering
# Entity Type: type of sport
# ---------------
# Freebase ID: /m/08hbxv
# Entity Name: Kosi Zone
# Entity Type: zone of Nepal
# ---------------
# Freebase ID: /m/018hzk
# Entity Name: cooking show
# Entity Type: television genre
# ---------------
# Freebase ID: /m/0gg81w
# Entity Name: educational television
# Entity Type: television genre
# ---------------
# Freebase ID: /m/04s84y
# Entity Name: general contractor
# Entity Type: profession
# ---------------
# Freebase ID: /m/01_30_
# Entity Name: Strategic Simulations
# Entity Type: video game developer
# ---------------
# Freebase ID: /m/01cgxp
# Entity Name: Mosul
# Entity Type: city
# ---------------
# Freebase ID: /m/01l5rz
# Entity Name: Grimsby
# Entity Type: town
# ---------------
# Freebase ID: /m/02qmjqd
# Entity Name: 2001 Major League Baseball season
# Entity Type: sports season
# ---------------
# Freebase ID: /m/01773g
# Entity Name: Stavanger
# Entity Type: municipality of Norway
# ---------------
# Freebase ID: /m/026_51
# Entity Name: Japanese mythology
# Entity Type: mythology
# ---------------
# Freebase ID: /m/0276krm
# Entity Name: fawn
# Entity Type: color
# ---------------
# Freebase ID: /m/02mxx4
# Entity Name: limited company
# Entity Type: legal form
# ---------------
# Freebase ID: /m/018s4
# Entity Name: BSD licenses
# Entity Type: OSI-approved license
# ---------------
# Freebase ID: /m/05ws7
# Entity Name: police
# Entity Type: government agency
# ---------------
# Freebase ID: /m/06w_b
# Entity Name: structured programming
# Entity Type: programming paradigm
# ---------------
# Freebase ID: /m/02cjrp
# Entity Name: bowler
# Entity Type: position
# ---------------
# Freebase ID: /m/02cmr1
# Entity Name: all-rounder
# Entity Type: position
# ---------------
# Freebase ID: /m/01zjn0
# Entity Name: Barrow-in-Furness
# Entity Type: town
# ---------------
# Freebase ID: /m/01zk9d
# Entity Name: St Andrews
# Entity Type: town
# ---------------
# Freebase ID: /m/0190_8
# Entity Name: Church of Scotland
# Entity Type: national Church
# ---------------
# Freebase ID: /m/01vpt5
# Entity Name: Greater Houston
# Entity Type: metropolitan statistical area
# ---------------
# Freebase ID: /m/01vz08
# Entity Name: Joseon
# Entity Type: historical country
# ---------------
# Freebase ID: /m/017ht
# Entity Name: bhangra
# Entity Type: music genre
# ---------------
# Freebase ID: /m/0x2jd
# Entity Name: Supreme Court of Canada
# Entity Type: supreme court
# ---------------
# Freebase ID: /m/0fr_v
# Entity Name: Paramaribo
# Entity Type: city
# ---------------
# Freebase ID: /m/08x9pc
# Entity Name: Imperial House of Japan
# Entity Type: dynasty
# ---------------
# Freebase ID: /m/050sw4
# Entity Name: contemporary hit radio
# Entity Type: radio format
# ---------------
# Freebase ID: /m/0d2mh7
# Entity Name: Bagrationi dynasty
# Entity Type: dynasty
# ---------------
# Freebase ID: /m/0mbx4
# Entity Name: child actor
# Entity Type: profession
# ---------------
# Freebase ID: /m/02pyg
# Entity Name: extreme sport
# Entity Type: type of sport
# ---------------
# Freebase ID: /m/015q02
# Entity Name: Perak
# Entity Type: state of Malaysia
# ---------------
# Freebase ID: /m/0_678
# Entity Name: tactical shooter
# Entity Type: video game genre
# ---------------
# Freebase ID: /m/0259tnd
# Entity Name: nonprofit organization
# Entity Type: industry
# ---------------
# Freebase ID: /m/02y_3rt
# Entity Name: alpha carotene (stereochemistry specified)
# Entity Type: type of chemical entity
# ---------------
# Freebase ID: /m/09dhj
# Entity Name: family
# Entity Type: social organization
# ---------------
# Freebase ID: /m/027752
# Entity Name: United National Party
# Entity Type: political party
# ---------------
# Freebase ID: /m/02y_93f
# Entity Name: surgeon
# Entity Type: academic degree
# ---------------
# Freebase ID: /m/03m5x4
# Entity Name: NBA Finals
# Entity Type: recurring sporting event
# ---------------
# Freebase ID: /m/01pwbn
# Entity Name: true crime
# Entity Type: non-fiction genre
# ---------------
# Freebase ID: /m/02p0zzf
# Entity Name: United States Army Air Corps
# Entity Type: military branch
# ---------------
# Freebase ID: /m/0blbx
# Entity Name: Glasnevin Cemetery
# Entity Type: cemetery
# ---------------
# Freebase ID: /m/02g982
# Entity Name: West Norwood Cemetery
# Entity Type: cemetery
# ---------------
# Freebase ID: /m/022qqh
# Entity Name: curator
# Entity Type: profession
# ---------------
# Freebase ID: /m/01t_1p
# Entity Name: contemporary worship music
# Entity Type: music genre
# ---------------
# Freebase ID: /m/05s0y9
# Entity Name: United States House Committee on Financial Services
# Entity Type: United States congressional committee
# ---------------
# Freebase ID: /m/047vnfs
# Entity Name: association football coach
# Entity Type: profession
# ---------------
# Freebase ID: /m/03ch14
# Entity Name: television special
# Entity Type: form of television program
# ---------------
# Freebase ID: /m/024030
# Entity Name: Padma Vibhushan
# Entity Type: award
# ---------------
# Freebase ID: /m/0gwj
# Entity Name: autism
# Entity Type: disability
# ---------------
# Freebase ID: /m/0p8bz
# Entity Name: Hamilton
# Entity Type: town
# ---------------
# Freebase ID: /m/09bv45
# Entity Name: CITV
# Entity Type: specialty channel
# ---------------
# Freebase ID: /m/016zxr
# Entity Name: Europop
# Entity Type: music genre
# ---------------
# Freebase ID: /m/05sz6
# Entity Name: Provisional Irish Republican Army
# Entity Type: paramilitary organization
# ---------------
# Freebase ID: /m/01803s
# Entity Name: immortality
# Entity Type: superpower
# ---------------
# Freebase ID: /m/02vq9j
# Entity Name: hereditary peer
# Entity Type: position
# ---------------
# Freebase ID: /m/0bk25
# Entity Name: Macedonia
# Entity Type: historical country
# ---------------
# Freebase ID: /m/01f99l
# Entity Name: Bath Iron Works
# Entity Type: shipyard
# ---------------
# Freebase ID: /m/03f_jk
# Entity Name: Lasker-DeBakey Clinical Medical Research Award
# Entity Type: science award
# ---------------
# Freebase ID: /m/05my9
# Entity Name: Orthodox Judaism
# Entity Type: Jewish religious movements
# ---------------
# Freebase ID: /m/01g4qq
# Entity Name: philanthropy
# Entity Type: activity
# ---------------
# Freebase ID: /m/0cqbc
# Entity Name: asteroid belt
# Entity Type: circumstellar disk
# ---------------
# Freebase ID: /m/0bwgmzd
# Entity Name: AACTA Award for Best Telefeature, Mini Series or Short Run Series
# Entity Type: AACTA Awards
# ---------------
# Freebase ID: /m/0f69h
# Entity Name: neo-Nazism
# Entity Type: social movement
# ---------------
# Freebase ID: /m/01qm7
# Entity Name: community college
# Entity Type: type of educational institution
# ---------------
# Freebase ID: /m/07svc3
# Entity Name: John Brown & Company
# Entity Type: business
# ---------------
# Freebase ID: /m/018zsw
# Entity Name: Canadian Army
# Entity Type: army
# ---------------
# Freebase ID: /m/050yl
# Entity Name: military history
# Entity Type: academic major
# ---------------
# Freebase ID: /m/012wvj
# Entity Name: Cumann na nGaedheal
# Entity Type: political party
# ---------------
# Freebase ID: /m/02wt_x
# Entity Name: multivariable calculus
# Entity Type: area of mathematics
# ---------------
# Freebase ID: /m/05swd
# Entity Name: propaganda film
# Entity Type: film genre
# ---------------
# Freebase ID: /m/037vqt
# Entity Name: James E. Sullivan Award
# Entity Type: sports award
# ---------------
# Freebase ID: /m/09ff3
# Entity Name: Cubism
# Entity Type: architectural style
# ---------------
# Freebase ID: /m/02p4pt3
# Entity Name: House of Plantagenet
# Entity Type: dynasty
# ---------------
# Freebase ID: /m/01mtt
# Entity Name: card game
# Entity Type: game genre
# ---------------
# Freebase ID: /m/02y_9cf
# Entity Name: Ethiopian Empire
# Entity Type: historical country
# ---------------
# Freebase ID: /m/068bs
# Entity Name: primary school
# Entity Type: educational stage
# ---------------
# Freebase ID: /m/03jjn8
# Entity Name: Liberal Party of the Philippines
# Entity Type: political party
# ---------------
# Freebase ID: /m/01z645
# Entity Name: Kettering
# Entity Type: town
# ---------------
# Freebase ID: /m/0k80c
# Entity Name: real-time strategy
# Entity Type: video game genre
# ---------------
# Freebase ID: /m/034wx3
# Entity Name: Brompton Cemetery
# Entity Type: cemetery
# ---------------
# Freebase ID: /m/0513yzt
# Entity Name: ballet dancer
# Entity Type: profession
# ---------------
# Freebase ID: /m/02r8dcw
# Entity Name: 1998 Major League Baseball season
# Entity Type: sports season
# ---------------
# Freebase ID: /m/0d8m3
# Entity Name: Pulitzer Prize for History
# Entity Type: class of award
# ---------------
# Freebase ID: /m/01fm_
# Entity Name: Social Democratic Party
# Entity Type: political party
# ---------------
# Freebase ID: /m/014bmh
# Entity Name: car bomb
# Entity Type: weapon functional class
# ---------------
# Freebase ID: /m/0fkv5
# Entity Name: Cichlidae
# Entity Type: taxon
# ---------------
# Freebase ID: /m/02z3cm0
# Entity Name: ECW Hardcore TV
# Entity Type: television series
# ---------------
# Freebase ID: /m/01g901
# Entity Name: far-right
# Entity Type: political alignment
# ---------------
# Freebase ID: /m/0dlj8q2
# Entity Name: Le Monde's 100 Books of the Century
# Entity Type: hall of fame
# ---------------
# Freebase ID: /m/046gm5
# Entity Name: Borjigin
# Entity Type: dynasty
# ---------------
# Freebase ID: /m/033th
# Entity Name: first-person shooter
# Entity Type: video game genre
# ---------------
# Freebase ID: /m/01k12m
# Entity Name: Dutch Golden Age
# Entity Type: golden age
# ---------------
# Freebase ID: /m/01pvc5
# Entity Name: jockey
# Entity Type: profession
# ---------------
# Freebase ID: /m/0fkrk
# Entity Name: Poaceae
# Entity Type: taxon
# ---------------
# Freebase ID: /m/02m97n
# Entity Name: Vickers-Armstrongs
# Entity Type: business
# ---------------
# Freebase ID: /m/02kysg
# Entity Name: students' union
# Entity Type: extracurricular activity
# ---------------
# Freebase ID: /m/07068
# Entity Name: samurai
# Entity Type: profession
# ---------------
# Freebase ID: /m/02070z
# Entity Name: killed in action
# Entity Type: manner of death
# ---------------
# Freebase ID: /m/09hljw
# Entity Name: tribal chief
# Entity Type: title
# ---------------
# Freebase ID: /m/02h661t
# Entity Name: dentist
# Entity Type: health profession
# ---------------
# Freebase ID: /m/02r74mj
# Entity Name: 1995 Major League Baseball season
# Entity Type: sports season
# ---------------
# Freebase ID: /m/03dfth
# Entity Name: contemporary philosophy
# Entity Type: academic discipline
# ---------------
# Freebase ID: /m/0zq7r
# Entity Name: Vertigo
# Entity Type: book publisher
# ---------------
# Freebase ID: /m/03ykjs9
# Entity Name: comedy
# Entity Type: theatrical genre
# ---------------
# Freebase ID: /m/0194x
# Entity Name: Baroque
# Entity Type: art movement
# ---------------
# Freebase ID: /m/04gbl3
# Entity Name: Ocean Software
# Entity Type: video game developer
# ---------------

# %%
import csv

output_csv_path = 'FB15K_Updated.csv'

with open(output_csv_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Freebase ID', 'Entity Name', 'Entity Type']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    for fb_id, info in FB15K_Updated.items():
        writer.writerow({
            'Freebase ID': fb_id,
            'Entity Name': info['entity_name'],
            'Entity Type': info['entity_type']
        })

# %%
len(entity_types)
# Out:
# 1066

# %%
entity_types
# Out:
# {'land-grant university',
#  'award for best leading actress',
#  'film',
#  'film festival',
#  'unitary authority area in England',
#  'river',
#  'corporation',
#  'designated intractable/rare disease',
#  'planned community',
#  'political movement',
#  'collection',
#  'province of Pakistan',
#  'seaside resort',
#  'ceremonial county of England',
#  'area of London',
#  'political ideology',
#  'type of world view',
#  'rebellion',
#  'political system',
#  'political alignment',
#  'county of West Virginia',
#  'type of musical instrument',
#  'major regional center',
#  'ice hockey position',
#  'religious identity',
#  'newspaper format',
#  'group of stereoisomers',
#  'programming paradigm',
#  'urban university',
#  'subsidiary',
#  'type of arts',
#  'interdisciplinarity',
#  'federative unit of Brazil',
#  'city in Ukraine',
#  'field of work',
#  'musical group',
#  'peninsula',
#  'university in Quebec',
#  'phase of human life',
#  'astronomical observatory',
#  'philosophical movement',
#  'form of festival',
#  'county of Arizona',
#  'game show',
#  'state of India',
#  'city in the United States',
#  'art school',
#  'award for best choreography',
#  'circumstellar disk',
#  'social class',
#  'state university system',
#  'special award',
#  'university college',
#  'county of Rhode Island',
#  'ethnic community',
#  'mental disorder',
#  'hall of fame',
#  'city of Illinois',
#  'dynasty',
#  'stop-motion animated television program',
#  'clay animation film',
#  'dog breed',
#  'musical profession',
#  'national cuisine',
#  'architectural typology',
#  'poetry award',
#  'execution method',
#  'borough of London Region',
#  'county of Maine',
#  'cultural movement',
#  'social behavior',
#  'type of sport',
#  'extremism',
#  'television',
#  'county of Colorado',
#  'form of art',
#  'tradition',
#  'megacity',
#  'broadcaster',
#  'municipality of Belgium',
#  'borough in the United Kingdom',
#  'political party',
#  'literary character',
#  'film award',
#  'organization',
#  'electoral unit',
#  'roadshow',
#  'multisports club',
#  'human biblical figure',
#  'marines',
#  'subject heading',
#  'daily newspaper',
#  'crime',
#  'professional wrestling promotion',
#  'British Academy Film Awards',
#  'art of painting',
#  'free imperial city',
#  'title of authority',
#  'architectural style',
#  'skyscraper',
#  'municipality of Brazil',
#  'type of educational institution',
#  'law school',
#  'television network',
#  'animated feature film',
#  'grande école',
#  'military campaign',
#  'specialty channel',
#  'library classification',
#  'rare disease',
#  'physics engine',
#  'county of Ireland',
#  'Wikibase reason for deprecated rank',
#  'cutout animation',
#  'type of work of art',
#  'medical specialty',
#  'type of musical work/composition',
#  'ethnoreligious group',
#  'institution',
#  'historic county of England',
#  'borough of Pennsylvania',
#  'television series genre',
#  'geographic region',
#  'disability',
#  'constitutional republic',
#  'title',
#  'urban municipality in Germany',
#  'terrorist organization',
#  'record label',
#  'dramatic work',
#  'award for best new actress',
#  'liberal arts college in the United States',
#  'municipality of the Netherlands',
#  'sports museum',
#  'military occupation',
#  'Poverty Row',
#  'OSI-approved license',
#  'United States federal agency',
#  'mode of transport',
#  'historical unrecognized state',
#  'building',
#  'internet television',
#  'ChEBI Ontology term',
#  "Critics' Choice Movie Award",
#  'Producers Guild of America Awards',
#  'historical country',
#  'high school',
#  'big city',
#  'liberal arts college',
#  "bachelor's degree",
#  'Christian school',
#  'county of Pennsylvania',
#  'province of the Netherlands',
#  'Grand Tour',
#  'status',
#  'infrastructure',
#  'communist party',
#  'former province of Italy',
#  'castle chapel',
#  'county of Texas',
#  'region of the Philippines',
#  'television series',
#  'country',
#  'chemical property',
#  'musical duo',
#  'literary award',
#  'clinical sign',
#  'public company',
#  'novel series',
#  'county town',
#  'new religious movement',
#  'mountain range',
#  'province of Indonesia',
#  'vice president',
#  'district of India',
#  'class of anatomical entity',
#  'Hong Kong Film Awards',
#  'taxonomic rank',
#  'municipality of Norway',
#  'official',
#  'invasion',
#  'basketball team',
#  'fiction genre',
#  'fantasy genre',
#  'executive branch',
#  'television special',
#  'manga series',
#  'local council of Malta',
#  'calendar month',
#  'navy',
#  'family of musical instruments',
#  'public university',
#  'comic publishing company',
#  'county of Florida',
#  'social organization',
#  'type of museum',
#  'charitable organization',
#  'service',
#  'administrative territorial entity',
#  'human',
#  'imprecise class of chemical entities',
#  'township of New Jersey',
#  'educational year',
#  'designation for an administrative territorial entity',
#  'cable channel',
#  'League of Nations mandate',
#  'championship',
#  'colony',
#  'work',
#  'island country',
#  'filmmaking occupation',
#  'conservation organization',
#  'drama school',
#  'group of chemical entities',
#  'college of the University of Oxford',
#  'retail chain',
#  'county of Illinois',
#  'independent record label',
#  'neighborhood in Boston',
#  'ecclesiastical occupation',
#  'county seat',
#  'language family',
#  'human social group',
#  'million city',
#  'lieutenancy area of Scotland',
#  'legislature',
#  'architectural style of an area',
#  'army',
#  'film festival edition',
#  'autonomous republic',
#  'game mode',
#  'literary class',
#  'programming language',
#  'university in France',
#  'political faction',
#  'landgraviate',
#  'rapid transit railway line',
#  'multi-sport event',
#  'historical region',
#  'architecture school',
#  'city of Pennsylvania',
#  'musical ensemble',
#  'American football team',
#  'county of New Hampshire',
#  'order',
#  'association football team',
#  'comedy troupe',
#  'national university',
#  'interpreted language',
#  'class of disease',
#  'British Academy Television Awards',
#  'behavior',
#  'social movement',
#  'award for best screenplay',
#  'vocal group',
#  'age of a person',
#  'criminal organization',
#  'ethnic minority group',
#  'product category',
#  'ideology',
#  'production company',
#  'thriller genre',
#  'Christian movement',
#  'architectural structure',
#  'parliamentary group',
#  'intergovernmental organization',
#  'vital record',
#  'aircraft functional class',
#  'town',
#  'episcopal conference',
#  'political philosophy',
#  'type of business entity in the United States',
#  'autonomous region',
#  'low-cost airline',
#  'educational canon',
#  'major religion',
#  'Unix-like operating system',
#  'object-based language',
#  'polis',
#  'AACTA Awards',
#  'literary form',
#  'county of Ohio',
#  'Academy Awards',
#  'poker tournament',
#  'Worldcon',
#  'film reboot',
#  'border city',
#  'cultural area',
#  'provinces of Prussia',
#  'human settlement',
#  'province of South Korea',
#  'comprehensive university',
#  'city in New Jersey',
#  'military academy',
#  'free software license',
#  'public broadcaster',
#  'film distributor',
#  'jam band',
#  'battle',
#  'coast guard',
#  'animation studio',
#  'Sportsperson of the Year',
#  'symptom',
#  'Tony Awards',
#  'school of education',
#  'metropolitan municipality in Turkey',
#  'rugby league team',
#  'model series',
#  'declaration of independence',
#  'type of animated work',
#  'comics character',
#  'ocean',
#  'county of Oregon',
#  'religious denomination',
#  'town in the United States',
#  'sub-province-level division',
#  'architectural firm',
#  'uji',
#  'French overseas collectivity',
#  'county of North Dakota',
#  'Scottish council area',
#  'ambiguous Wikidata item',
#  'crematorium',
#  'health risk',
#  'gameplay experience',
#  'tennis court',
#  'world war',
#  'operating system',
#  'broadcast network',
#  'peace award',
#  'book series',
#  'global city',
#  'insular area of the United States',
#  'multilateral development bank',
#  'electromechanical instruments',
#  'village',
#  'board game publishing company',
#  'anagram',
#  'activity',
#  'Satellite Awards',
#  'anthology film',
#  'mobile operating system',
#  'county of Oklahoma',
#  'G-type main-sequence star',
#  'endemic disease',
#  'Alpine section',
#  "children's television series",
#  'anime film',
#  'unicase alphabet',
#  'equine coat color',
#  'county of Missouri',
#  'historical period',
#  'municipality of Finland',
#  'live-action animated film',
#  'neighborhood',
#  'WWE programs',
#  'foundation',
#  'voice type',
#  'satellite city',
#  'medical school',
#  'diaspora or migration by origin country/region/continent',
#  'county of South Carolina',
#  'legislative term',
#  'profession',
#  'type of musical ensemble/group',
#  'public holiday',
#  'intifada',
#  'form of government',
#  'Catholic university',
#  'cause of death',
#  'central university',
#  'diet',
#  'social issue',
#  'principal area of Wales',
#  'disease',
#  'National Board of Review Awards',
#  'house of commons',
#  'paramilitary organization',
#  'Golden Raspberry Awards',
#  'green party',
#  'class of mythical entities',
#  'television station',
#  'educational stage',
#  'job activity',
#  'football club',
#  'copyleft free software license',
#  'television program',
#  'county of Michigan',
#  'United States federal executive department',
#  'musical instrument model',
#  'type of business entity',
#  'event',
#  'ice hockey team',
#  'city',
#  "director's cut",
#  'branch of philosophy',
#  'tourist destination',
#  'television film',
#  'archipelago',
#  'film studio',
#  'essentially contested concept',
#  'enclave',
#  'sea',
#  'county of Delaware',
#  'superior planet',
#  'fixed-base operator',
#  'resort town',
#  'second-order class',
#  'commune of France',
#  'film series',
#  'extracurricular activity',
#  'religious movement',
#  'kernel',
#  'currency',
#  'strait',
#  'municipality of Spain',
#  'master of ceremonies',
#  'city of Indonesia',
#  'collegiate university',
#  'fictional universe',
#  'association football club',
#  'cuisine',
#  'television production company',
#  'national park',
#  'humor magazine',
#  'book publisher',
#  'county of Kansas',
#  'castle',
#  'district capital',
#  'type of cinematic work',
#  'business',
#  'main stream',
#  'horror genre',
#  'non-geologically related mountain range',
#  'nonprofit organization',
#  'borough of New York City',
#  'highly urbanized city',
#  'aviation ministry',
#  'Writers Guild of America Award',
#  'medical finding',
#  'code of conduct',
#  'notifiable disease',
#  'educational organization',
#  'ethnic group',
#  'state of Australia',
#  'infectious disease',
#  'failure mode',
#  'autonomous university',
#  'autonomous region with special statute',
#  'state',
#  'recurring sporting event',
#  'article',
#  'phenomenon',
#  'educational institution',
#  'radio format',
#  'input device',
#  'sub-set of literature',
#  'Los Angeles Film Critics Association Awards',
#  'civil war',
#  'standard variety',
#  'volcanic landform',
#  'genre',
#  'boarding school',
#  'school',
#  'village of New Jersey',
#  'animated television series',
#  'faculty',
#  'order of chivalry',
#  'train and rail category',
#  'academic discipline',
#  'province of Argentina',
#  'noble family',
#  'false imprisonment',
#  'colonial society',
#  'natural language',
#  'county of North Carolina',
#  'American football position',
#  'census-designated place in the United States',
#  'university association',
#  'province of the Philippines',
#  'century',
#  'gay village',
#  'supreme court',
#  'statutory city in Czechia',
#  'community',
#  'ranked list',
#  'urban area',
#  'academy of sciences',
#  'drug',
#  'high-level programming language',
#  'British Independent Film Awards',
#  'Christian Church',
#  'New York Film Critics Circle Awards',
#  'professional degree',
#  'bicameral legislature',
#  'film genre',
#  'video game developer',
#  'municipality of Catalonia',
#  'sports award',
#  'golden age',
#  'bass',
#  'information',
#  'major label',
#  'free operating system',
#  'mainland',
#  'concept',
#  'building complex',
#  'boy band',
#  'novel genre',
#  'title of honor',
#  'speculative/fantastic fiction genre',
#  'organisms known by a particular common name',
#  'MTV Movie & TV Awards',
#  'county of Georgia',
#  'major command of the United States Army',
#  'statutory city of Austria',
#  'former administrative territorial entity',
#  'bridge by structural type',
#  'county of Tennessee',
#  'county of Washington',
#  'video game publisher',
#  'video game genre',
#  'structural class of chemical entities',
#  'class of award',
#  'public educational institution of the United States',
#  'county of Maryland',
#  'British overseas territories',
#  'professional sports league',
#  'property crime',
#  'musical instrument',
#  'Tony Awards ceremony',
#  'crossover fiction',
#  'academic department',
#  'original video animation series',
#  'government agency',
#  'sports discipline',
#  'county of Montana',
#  'borough of New Jersey',
#  'brick and mortar',
#  'metropolitan area',
#  'region of Italy',
#  'feature film',
#  'autonomous province of Serbia',
#  'aircraft family',
#  'recurring event',
#  'county of Massachusetts',
#  'religious text',
#  'county of New Jersey',
#  'port settlement',
#  'home video game console model',
#  'U.S. state',
#  'form of state',
#  'Canadian legislative assembly',
#  'publisher',
#  'place type',
#  'political party in Germany',
#  'orders, decorations, and medals of the United Kingdom',
#  'cemetery',
#  'corporate title',
#  'umbrella organization',
#  'heavy metal band',
#  'road',
#  'county of Nevada',
#  'arboretum',
#  'lifestyle',
#  'brand',
#  'Jewish religious movements',
#  'stock character',
#  'company',
#  'software category',
#  'macrolanguage',
#  'research institute',
#  'Pulitzer Prize',
#  'department of France',
#  'radio network',
#  'traditionally animated film',
#  'building type',
#  'World Athletics Championships',
#  'county of Vermont',
#  'racism',
#  'superpower',
#  'internet service provider',
#  'dictionary page in Wikipedia',
#  'jurisdiction',
#  'superstition',
#  'exact science',
#  'software',
#  'county of Wisconsin',
#  'technical standard',
#  'rock band',
#  'musical concept',
#  'shipyard',
#  "women's college",
#  'prefecture-level city',
#  'object form',
#  'census area of Alaska',
#  'state order',
#  'consolidated city-county',
#  'Primetime Emmy Award annual ceremony',
#  'dependent territory',
#  'term of the Canadian federal parliament',
#  'music award',
#  'conflict',
#  'Hundred Flowers Awards',
#  'higher education institution',
#  'combined statistical area',
#  'animated film series',
#  'research university',
#  'military rank',
#  'city of New Brunswick',
#  'baseball position',
#  'video game character',
#  'horse breed',
#  'pontifical university',
#  'public–private partnership',
#  'province of Italy',
#  'city district',
#  'intelligence agency',
#  'air force academy',
#  'publication',
#  'armed forces',
#  'interdisciplinary science',
#  'municipality of Switzerland',
#  'complication',
#  'canton of Switzerland',
#  'sports club',
#  'film format',
#  'county of Hawaii',
#  'institute of technology',
#  'province of Spain',
#  'head of state',
#  'United States presidential election',
#  'family',
#  'electronic device model',
#  'ethical theory',
#  'house of lords',
#  'lake',
#  'heritage register',
#  'historically black colleges and universities',
#  'religious war',
#  'computer-animated film',
#  'web portal',
#  'economic system',
#  'noble title',
#  'state of Mexico',
#  'middleware',
#  'yearly prize',
#  'university campus',
#  'database',
#  'popular front',
#  'Tour de France',
#  'air force',
#  'county of Nebraska',
#  'award for best direction',
#  'academic institution',
#  'European Film Awards',
#  'province of China',
#  'United States congressional district',
#  'war',
#  'form of television program',
#  'color',
#  'stock exchange',
#  'county of Minnesota',
#  'award for best supporting actress',
#  'city in the state of New York',
#  'community college',
#  'group or class of chemical substances',
#  'Primetime Emmy Award',
#  'astronomical object type',
#  'music genre',
#  'bowl game',
#  'fictional detective',
#  'musical movement',
#  'radio station',
#  'state of Malaysia',
#  'film production company',
#  'photograph',
#  'administrative territorial entity of Bosnia and Herzegovina',
#  'literary term',
#  'university in Ontario',
#  'city of Iran',
#  'religious organization',
#  'private not-for-profit educational institution',
#  'independent city',
#  'national Church',
#  'musical film',
#  'animated film',
#  'cultural region',
#  'biogenic substance type',
#  'centerfold',
#  'basketball position',
#  'city-state',
#  'military profession',
#  'capital region',
#  'function',
#  'independent agency of the United States government',
#  'award for best photography',
#  'anime television series',
#  'county of New York',
#  'guitar technique',
#  'city in British Columbia',
#  'group of isomeric entities',
#  'science award',
#  'specialty',
#  'special ward of Japan',
#  'artistic technique',
#  'volcanic island',
#  'Australian rules football club',
#  'art museum',
#  'seminary',
#  'county of Arkansas',
#  'campus university',
#  'concert tour',
#  'sports season',
#  'science fiction genre',
#  'medication',
#  'conservatory',
#  'metropolitan statistical area',
#  'Christian denominational family',
#  'house of representatives',
#  'time zone',
#  'religion',
#  'metropolitan city of South Korea',
#  'capital city',
#  "men's association football club",
#  'human impact on the environment',
#  'empire',
#  'monster',
#  'kingdom',
#  'independent school',
#  'public research university',
#  'venture capital firm',
#  'human population',
#  'region of Japan',
#  'home rule municipality of Pennsylvania',
#  'Winter Olympic Games',
#  'register',
#  'suspension bridge',
#  'abbey church',
#  'national sports team',
#  'theater of war',
#  'school of thought',
#  'county of Connecticut',
#  'project',
#  'supergroup',
#  'inflammatory disease',
#  'type of record label',
#  'president',
#  'Ortsteil',
#  'city of Japan',
#  'ethnic group by residency',
#  'mainland territory of Australia',
#  'state city of Latvia',
#  'international financial institution',
#  'national association football team',
#  'baseball team',
#  'music tradition',
#  'revolution',
#  'chemical element',
#  'type foundry',
#  'unincorporated community in the United States',
#  'violence',
#  'United States congressional committee',
#  'human hair color',
#  'neighborhood in Queens',
#  'minor basilica',
#  'Screen Actors Guild Award',
#  'National Football League Draft',
#  'civil decoration',
#  'excipient',
#  'scandal',
#  'county of Croatia',
#  'private school',
#  'international sport governing body',
#  'class',
#  'cinematic technique',
#  'television pilot',
#  'website',
#  'Catholic order',
#  'television channel',
#  'theatre award',
#  'news program',
#  'human rights',
#  'reserve team',
#  'film award category',
#  'legal concept',
#  'diaspora or migration by origin and host country',
#  'national cricket team',
#  'journalism school',
#  'manner of death',
#  'railway company',
#  'world view',
#  'suburb of Perth',
#  'Genie Awards',
#  'international organization',
#  'Japan Academy Film Prize',
#  'fraternity',
#  'college of the University of Cambridge',
#  'metallic color',
#  'health profession',
#  'county of Utah',
#  'computer science term',
#  'duo',
#  'writing system',
#  'career',
#  'physical media format',
#  'type of organisation',
#  'district',
#  'heritage designation',
#  'county of Wyoming',
#  'primary school',
#  'Nebula Award',
#  'proxy war',
#  '3D film',
#  'mythology',
#  'award for best newcomer',
#  'award for best supporting actor',
#  'remake',
#  'religious occupation',
#  'type of food or dish',
#  'dialect',
#  'film character',
#  'credit institution',
#  'area of mathematics',
#  'non-metropolitan district',
#  'position',
#  'parish of Louisiana',
#  'biological sex',
#  'Wissenschaft',
#  'congressional caucus',
#  'cinema by country or region',
#  'technology',
#  'National Basketball Association draft',
#  'multinational corporation',
#  'award for best performance',
#  'archive',
#  'festival',
#  'magnet school',
#  'term',
#  'miniseries',
#  'Cannes Film Festival Awards',
#  'most valuable player award',
#  'series of wars',
#  'sorority',
#  'spin-off',
#  'Olympic sport',
#  'Chicago Film Critics Association Awards',
#  'human race',
#  'Golden Globe Award',
#  'civil liberties',
#  'theatrical genre',
#  'association football position',
#  'traditional animation',
#  'dominion of the British Empire',
#  'type of war',
#  'animation technique',
#  'federal state of Austria',
#  'private university',
#  'Grammy Awards',
#  'division',
#  'magazine genre',
#  'province of Canada',
#  'occupied territory',
#  'ethnic group in Indonesia',
#  'Canadian football club',
#  'conservation designation',
#  'legal status of medicine',
#  'defunct association football club',
#  'learning disability',
#  'planetary system',
#  'comedic genre',
#  'United States senior military college',
#  'university-preparatory school',
#  'open-access publisher',
#  'literary genre',
#  'sovereign state',
#  'plucked string instrument',
#  'art movement',
#  'award for best leading actor',
#  'double feature',
#  'medium regional center',
#  'cricket team',
#  'food group',
#  'NRHP district',
#  'business school',
#  'ethnic conflict',
#  'metric',
#  'province of South Africa',
#  'county of California',
#  'nation',
#  'circus profession',
#  'voivodeship of Poland',
#  'postgraduate degree',
#  'occupation',
#  'software feature',
#  'real estate investment trust',
#  'married couple',
#  'type of chemical entity',
#  'applied science',
#  'county of Northern Ireland',
#  'cinema film format',
#  'county of Indiana',
#  'revenue service',
#  'palace',
#  'secret society',
#  'horse',
#  'medallion',
#  'island of Japan',
#  'sexual orientation',
#  'war front',
#  'television series season',
#  'selective school',
#  'student society',
#  'record company',
#  'literary element',
#  'set',
#  'symptom or sign',
#  'terrestrial planet',
#  'pandemic',
#  'architectural heritage monument',
#  'culture',
#  'department of parks and recreation',
#  'branch of science',
#  'sports competition',
#  'county of Iowa',
#  'Unix',
#  "master's degree",
#  'automobile manufacturer',
#  'district or neighborhood of Los Angeles',
#  'municipality of Puerto Rico',
#  'Wikimedia list article',
#  'county of Alabama',
#  'county of New Mexico',
#  'bank',
#  'class of chemical entities with similar source or occurrence',
#  'economic ideology',
#  'formal science',
#  'taxon',
#  'television genre',
#  'emotion',
#  'administrative territorial entity of New Zealand',
#  'mixture',
#  'scholarship',
#  'non-fiction genre',
#  'cycling city',
#  'Filmfare Awards',
#  'urban area in Sweden',
#  'Independent Spirit Awards',
#  'zone of Nepal',
#  'music award category',
#  'trademark',
#  'consonant letter',
#  'suburb',
#  'county of Kentucky',
#  'product distribution method',
#  'university in Newfoundland and Labrador',
#  'Summer Olympic Games',
#  'federal subject of Russia',
#  'Christian denomination',
#  'sweetener',
#  'electronics',
#  'hypothesis',
#  'Golden Globe Award ceremony',
#  'airline alliance',
#  'field of study',
#  'National Society of Film Critics Award',
#  'college',
#  'holding company',
#  'conglomerate',
#  'minority group',
#  'sports hall of fame',
#  'territory of Canada',
#  'female idol group',
#  'group of awards',
#  'radio program',
#  'Latin-script alphabet',
#  'art genre',
#  'inner planet of the Solar System',
#  'military alliance',
#  'language',
#  'Hanseatic city',
#  'rock type',
#  'sports league',
#  'commune of Italy',
#  'Academy Awards ceremony',
#  'media franchise',
#  'radio genre',
#  'New England town',
#  'game genre',
#  'classification in sports',
#  'software license',
#  'lower house',
#  'philosophical concept',
#  'award ceremony',
#  'airline',
#  "men's association football team",
#  'military operation',
#  'academic major',
#  'courage award',
#  'public office',
#  ...}
